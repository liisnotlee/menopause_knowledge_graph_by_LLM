# %%
import json
import os
from glob import glob

INPUT_DIR = "/Users/cj2837/Documents/Courses/Project/extraction_outputs/"
json_files = glob(os.path.join(INPUT_DIR, "*.json"))

raw_all_triples = []

def extract_triples_from_json(data):
    triples = []

    # Case A: dict of studies
    if isinstance(data, dict):
        for v in data.values():
            if isinstance(v, str):            # handle string-encoded JSON
                v = json.loads(v)
            if isinstance(v, list):
                triples.extend(v)

    # Case B: a single list
    elif isinstance(data, list):
        triples.extend(data)

    return triples


# Loop over files
for fpath in json_files:
    with open(fpath, "r") as f:
        data = json.load(f)
    triples = extract_triples_from_json(data)
    raw_all_triples.extend(triples)

print(f"Total triples collected: {len(raw_all_triples)}")
# Out:
# ✅ Total triples collected: 1322

# %%
# covert all nodes to lowercase
all_triples = [
    {key: (value.lower() if isinstance(value, str) else value) for key, value in item.items()}
    for item in raw_all_triples
]

# %%
node_names = set()

for t in all_triples:
    node_names.add(t["head"])
    node_names.add(t["tail"])

print("Total unique node names:", len(node_names))
# Out:
# Total unique node names: 1069

# %%
edge_names = set()

for t in all_triples:
    edge_names.add(t["relation"])

print("Total unique edge names:", len(edge_names))
# Out:
# Total unique edge names: 303

# %%
nodetype_names = set()

for t in all_triples:
    nodetype_names.add(t["head_type"])
    nodetype_names.add(t["tail_type"])

print("Total unique node type names:", len(nodetype_names))
# Out:
# Total unique node type names: 29

# %% [markdown]
# ## Cleaning step 1: remove parenthesis
#
# Parenthesis contains synonyms or extra details that are not that useful but causes trouble for mapping

# %%
import re

nodes_with_paren = set()

for t in all_triples:
    for node in [t["head"], t["tail"]]:
        if node and re.search(r"\(.*\)", node):   # contains (...) with anything inside
            nodes_with_paren.add(node)

print(f"Found {len(nodes_with_paren)} nodes containing parentheses:\n")
for n in sorted(nodes_with_paren):
    print("-", n)
# Out:
# Found 96 nodes containing parentheses:
#
# - acquired generalized hypoactive sexual desire disorder (hsdd)
# - antidepressants (ssris and snris)
# - antidepressants (ssris, snris)
# - ba058 (abaloparatide)
# - bay3427080 (nt-814)
# - birth control pills, antidepressants (ssris and snris), gabapentin, fezolinetant, oxybutynin
# - body mass index (bmi)
# - bone mineral density (bmd)
# - bone mineral density (bmd) of femoral neck
# - bone mineral density (bmd) of lumbar spine
# - bone mineral density (bmd) of lumbar spine (l2-l4)
# - bone mineral density (bmd) of total hip
# - bone-specific alkaline phosphatase (bsap)
# - boniva confidence scale (bcs)
# - bonviva (ibandronate)
# - bonviva (ibandronate) treatment
# - bonviva/boniva (ibandronate)
# - change from baseline in follicle-stimulating hormone (fsh) level
# - change in bone mineral density (bmd) of axial lumbar spine
# - change in montgomery-asperg depression rating scale (madrs)
# - change in plasma c-terminal telopeptide of collagen 1 (ctx-1)
# - cumulative incidence of venous thromboembolism (vte)
# - decreased health-related quality of life (hrqol)
# - effects of timely menopausal hormone therapy (mht)
# - estradiol (e2)
# - estrogen feedback on luteinizing hormone (lh)
# - estrogen progestogen therapy (ept)
# - estrogen therapy (et)
# - female sexual function index (fsfi) - total score
# - female sexual function index (fsfi) domain score - arousal
# - female sexual function index (fsfi) domain score - lubrication
# - female sexual function index (fsfi) domain score - pain
# - female sexual function index (fsfi) domain score - satisfaction
# - follicle stimulating hormone (fsh)
# - follicle-stimulating hormone (fsh)
# - gonadotropin-releasing hormone (gnrh)
# - gonadotropin-releasing hormone agonist (gnrha)
# - greene climacteric scale (gcs)
# - hormone replacement therapy (hrt)
# - hormone therapy (ht)
# - hormone therapy (ht) discontinuation
# - hormone therapy (ht) use
# - hot flash-related daily interference scale (hfrdis)
# - inventory of depression and anxiety symptoms (idas) dysphoria scores
# - irregular heartbeat (palpitations)
# - kronos early estrogen prevention study (keeps)
# - leeds sleep evaluation questionnaire (lseq) domain scores
# - levonorgestrel intrauterine system (lng ius)
# - long life study (lls)
# - lumbar spine areal bone mineral density (bmd)
# - lumbar spine bone mineral density (bmd)
# - luteinizing hormone (lh)
# - maturation index of vaginal cell type (intermediate cells)
# - maturation index of vaginal cell type (parabasal cells)
# - maturation index of vaginal cell type (superficial cells)
# - menopausal hormone therapy (mht)
# - menopause-specific quality of life (menqol)
# - myalgic encephalomyelitis/chronic fatigue syndrome (me/cfs)
# - n-terminal propeptide of type 1 collagen (p1np)
# - national heart, lung, and blood institute (nhlbi)
# - novel menopause hormone therapy (conjugated estrogen/bazedoxifene [ce/bza])
# - objective physical activity and cardiovascular health study (opach)
# - percent change in wake after sleep onset (waso)
# - post-traumatic stress disorder (ptsd)
# - premenstrual syndrome (pms)
# - primary ovarian insufficiency (poi)
# - production of myeloid adipocyte progenitors (maps)
# - progranulin (pgrn)
# - resting energy expenditure (ree)
# - selective serotonin reuptake inhibitors (ssris)
# - serum bone-specific alkaline phosphatase (s-bsap)
# - serum c-telopeptide-i (ctx-i)
# - serum c-telopeptides of type i collagen (s-ctx)
# - serum c-terminal propeptide of type 1 collagen (s-ctx)
# - serum c-terminal telopeptide of type 1 collagen (sctx)
# - serum carboxyterminal cross-linking telopeptide of type i collagen (ctx)
# - serum n-terminal propeptide (s-p1np)
# - serum procollagen type i n-terminal propeptide (pinp)
# - sexually transmitted infections (stis)
# - sleeping problems (insomnia)
# - study of women’s health across the nation (swan)
# - tissue selective estrogen complex (tsec)
# - total hip bone mineral density (bmd)
# - urinary n-telopeptides of type i collagen/creatinine (u-ntx/cr) ratio
# - urinary-n telopeptides of type 1 collagen (u-ntx)
# - vaginal mucosa assessment (vaginal color)
# - vaginal mucosa assessment (vaginal epithelial integrity)
# - vaginal mucosa assessment (vaginal epithelial surface thickness)
# - vasomotor symptoms (vms)
# - volumetric bone mineral density (bmd) of hip
# - volumetric bone mineral density (bmd) of lumbar spine
# - warfarin (coumadin)
# - women taking hormone replacement therapy (hrt)
# - women's health initiative (whi)
# - women's health initiative sleep hypoxia effects on resilience (whisper)
# - women's health initiative strong and healthy study (whish)

# %%
# remove parenthesis
import re

def strip_parentheses(text):
    if not text:
        return text
    # Remove all (...) including content
    text = re.sub(r"\(.*?\)", "", text)
    # Remove extra spaces created by removal
    text = re.sub(r"\s+", " ", text)
    return text.strip()

# %%
cleaned_triples = []

for t in all_triples:
    cleaned_triples.append({
        **t,
        "head": strip_parentheses(t["head"]),
        "tail": strip_parentheses(t["tail"])
    })

# %% [markdown]
# ## UMLS Mapping

# %%
node_names = set()

for t in cleaned_triples:
    node_names.add(t["head"])
    node_names.add(t["tail"])

print("Total unique node names:", len(node_names))
# Out:
# Total unique node names: 1047

# %%
import requests, time

api_key = ""
BASE_URL = "https://uts-ws.nlm.nih.gov/rest/search/current"

def umls_lookup(term):
    params = {
        "string": term,
        "apiKey": api_key,
        "searchType": "words",         # less strict than "exact"
        "approximateMatch": "true",    # allow fuzzy matching
        "returnIdType": "concept"      # return CUI
    }
    try:
        r = requests.get(BASE_URL, params=params)
        r.raise_for_status()
        data = r.json()
        results = data.get("result", {}).get("results", [])

        if results:
            top = results[0]

            return {
                "CUI": top.get("ui"),
                "preferred_name": top.get("name"),
                "semantic_source": top.get("rootSource")
            }

        return {"CUI": None, "preferred_name": None, "semantic_source": None}

    except Exception:
        return {"CUI": None, "preferred_name": None, "semantic_source": None}

# %%
umls_map = {}

for term in node_names:
    umls_map[term] = umls_lookup(term)

# %%
mapped = {k:v for k,v in umls_map.items() if v["CUI"]}
unmapped = {k:v for k,v in umls_map.items() if v["CUI"] is None}

print("Mapped:", len(mapped))
print("Unmapped:", len(unmapped))
# Out:
# Mapped: 574
# Unmapped: 473

# %%
unmapped
# Out:
# {'having sex more often': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'vaginal wall degradative activity': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'sleep adequacy': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'perimenopausal and postmenopausal women': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'non-hormonal medicine': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'lifestyle changes, nonhormonal medications, and hormones': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'low-dose hormonal birth control': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'oral calcitonin': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'chronological aging': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'bone turnover markers': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'higher body mass index': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'surgery to remove both ovaries': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'prolonged estrogen use': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'bone mineral density of the femoral neck': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'diminished sex hormone levels': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'serum c-telopeptides of type i collagen': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'comfortable sex': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'boniva confidence scale': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'within 10 years of menopause': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'health during and after menopause': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'flu, covid-19, pneumonia, shingles, rsv': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'my menoplan website': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'loss of height due to bone loss': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'estrogen pill, patches and creams': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'ovaries stop releasing eggs': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'menopause research': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'hormone fluctuations': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  "women's health initiative": {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'brown adipose tissue activity': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'vaginal bleeding after menopause': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'health history, age and other factors': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'production of inflammatory bone marrow-derived adipocytes': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'severity of hot flushes': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'mild discomfort during sex': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'cumulative incidence of ischemic stroke': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'lower levels of estrogen and progesterone': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'serum n-terminal propeptides of type 1 collagen level': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'moisture in vaginal tissues': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'changes in cholesterol levels': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'putamen signal intensity': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'trabecular bmd at the distal tibia': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'low-dose 17-ß-estradiol': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'estimate of bone strength of lumbar spine': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'mean hip bone bmd': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'menopause-related sleep fragmentation': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'activation frequency in cancellous compartment': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'percent change from baseline at month 24': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'regular pap tests': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'over-the-counter vaginal moisturizers': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'pooled clinical vertebral and non-vertebral fragility fractures': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'hormonal changes due to menopause': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'maturation index of vaginal cell type': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'total bmd at the distal tibia': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'bone loss and osteoporosis': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'pooled new and worsening vertebral fractures': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'people experiencing menopause before age 40': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'low-dose estradiol mht': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'heavy or irregular periods': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'frequency of moderate to severe vasomotor symptoms': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'bone formation rate in endocortical compartment': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'premenopausal-aged female veterans': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'effects of phytoestrogens are inconsistent': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'change from baseline in serum procollagen type i n-terminal propeptide': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'joint/muscular discomfort': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'cumulative incidence of renal failure': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'increased serum sost level': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'estrogen production decline': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'hormone therapy for breast cancer': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'risk of cognitive decline': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'women with history of blood clots': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'cumulative incidence of hypertriglyceridemia': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'mean daily severity of hot flashes': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  "women's health initiative sleep hypoxia effects on resilience": {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'prevention of osteoporosis-related fractures': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'my menoplan': {'CUI': None, 'preferred_name': None, 'semantic_source': None},
#  'depression during menopause transition': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'total hip integral bone mineral content': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'nonhormonal medications': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'joining support groups': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'early onset of menopause': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'differences in bile acid metabolism': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'bone density of the total hip': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'cumulative incidence of venous thromboembolism': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'long-term opioid prescription patterns': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'task force from several professional societies': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'adverse leptin response': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'cumulative incidence of selected ocular events': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'cumulative incidence of clinical fractures': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'carrying a portable fan': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'good safety records': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'serum 25-hydroxyvitamin d <20 ng/ml': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'number of participants with mean percent reduction of 90% in the mean frequency of moderate and severe vms': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'undercarboxylated osteocalcin/osteocalcin ratio': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'routine use of dhea': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'decreased interest in sex': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'more severe menopause symptoms': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'estradiol vaginal softgel capsules': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'msbrain i': {'CUI': None, 'preferred_name': None, 'semantic_source': None},
#  'blood flow to the vagina': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'women after age 40 through age 75': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'vaginal mucosa assessment': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'bones to become brittle and weak': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'alendronate/vitamin d3 combination tablet': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'new vertebral fractures': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'black women': {'CUI': None, 'preferred_name': None, 'semantic_source': None},
#  'mid-40s': {'CUI': None, 'preferred_name': None, 'semantic_source': None},
#  'soy containing foods': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'increased risk for alzheimer’s disease': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'women and healthcare providers make informed decisions': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'vaginal hormone tablet': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'lower chance of death': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'immediate menopause symptoms': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  '52 years old': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'increased enjoyment of sex': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'relieving moderate to severe symptoms early in menopause': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'msbrain': {'CUI': None, 'preferred_name': None, 'semantic_source': None},
#  'mood swings, hot flashes, and other symptoms': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'areal bmd at ⅓ distal radius': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'cortical bmd at the distal radius': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'women even after menopause': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'mean frequency of mild, moderate, and severe vms': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'number of participants with absolute reduction of 5 in mean number of mild, moderate and severe vms per day': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'inflammatory disorders such as rheumatoid arthritis and postmenopausal osteoporosis': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'north american menopause society': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'apoe ε 4': {'CUI': None, 'preferred_name': None, 'semantic_source': None},
#  'post-menopausal women': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'simulated acupuncture': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'long life study': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'blood, urine, and other tests': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'two to eight years': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'longer than necessary': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'whi community prevention study': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'local vaginal treatments': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'bonviva treatment': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'more menopausal symptoms': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'tx-12-004-hr': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'mean composite daily severity of hot flashes': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'menopause-focused mobile app': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'first few years after last period': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'post-menopausal vasomotor symptoms': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'hcol1a1': {'CUI': None, 'preferred_name': None, 'semantic_source': None},
#  'inventory of depression and anxiety symptoms dysphoria scores': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'uncomfortable physical and emotional symptoms': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'areal bmd at the lumbar spine': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'serum c-telopeptides of type 1 collagen level': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'muscles involved in orgasm': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'different estrogen preparation': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'muscles of vagina and pelvis': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'missing chromosomes': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'female sexual function index - total score': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'body shape and composition': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'treatment for vaginal symptoms associated with menopause': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'severity of vasomotor symptoms': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'women taking hormone replacement therapy': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'symptoms and treatments of menopause': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'loss of estrogen': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'mean percent reduction of mild, moderate, and severe vms': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'vaginal dryness and painful sexual intercourse': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'birth control pills, antidepressants , gabapentin, fezolinetant, oxybutynin': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'protection against steatosis in females': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'integral bone mineral density': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'other forms of hormone therapy': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'sost level': {'CUI': None, 'preferred_name': None, 'semantic_source': None},
#  'serum carboxy-terminal cross-linking telopeptide of type i collagen': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'menopausal ovarian aging': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'urinary deoxypyridinoline/creatinine ratio': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'vasomotor symptoms, cardiovascular health, sleep, cognition, brain function and structure': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'cumulative incidence of biliary events': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  "women's health initiative strong and healthy study": {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'no longer get pregnant': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'distal 1/3 radius bmd': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'lower dose of estrogen': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'longer arousal time': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'objective physical activity and cardiovascular health study': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'hormone replacement therapy did not prevent heart disease': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'nonprescription, water-based lubricant': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'increased arterial stiffness': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'greater risk of cardiovascular disease': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'natural biological occurrence': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'average daily severity of hot flushes': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'periods that occur very close together': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'percent change in wake after sleep onset': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'number of participants with mean percent reduction of 50% in the mean frequency of moderate and severe vms': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'cogmax': {'CUI': None, 'preferred_name': None, 'semantic_source': None},
#  'weakened bladder muscles': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'vaginal estrogen treatments': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'greater risk for heart disease': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'menopause-related changes in brain health': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'women who started menopause many years ago': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'bone mineral density at trochanter': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'acne or greasy skin': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'mean severity of moderate and severe vms': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'women who have recently entered menopause': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'changes in hormone levels': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'number of participants with absolute reduction of 3 in mean number of mild, moderate and severe vms per day': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'bone mineral density at the lumbar spine': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'change in montgomery-asperg depression rating scale': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'cortical volumetric bmd of the hip': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'menopause knowledge': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'bone in postmenopausal osteoporotic women': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'serum c-terminal telopeptide of type 1 collagen': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'protection against steatosis': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'cholesterol buildup': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'vasomotor domain score': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'frequency of vasomotor symptoms': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'nccih-funded researchers': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'femoral neck bone mineral density': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'proliferative effects': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'bothersome vaginal symptoms': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'number of participants with absolute reduction of 4 in mean number of mild, moderate and severe vms per day': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  '18 fdg uptake at the pituitary': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'dkk-1 level': {'CUI': None, 'preferred_name': None, 'semantic_source': None},
#  'women with liver disease': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'postmenopausal symptom complex': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'number of participants with mean percent reduction of 50% in the mean frequency of mild, moderate, and severe vms': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'n-terminal propeptide of type 1 collagen': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'obese menopausal women veterans with prediabetes and early diabetes': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'lumbar spine areal bone mineral density': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'women up to age 59': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'changing hormone levels': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'uterine lining': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'self-reported sleep quality': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'hormone levels change randomly': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'total hip bone mineral density': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'serum bone specific alkaline phosphatase level': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'change from baseline in follicle-stimulating hormone level': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  '160 of the 230 participants from msbrain i': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'bone formation rate in cancellous compartment': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'periods that last longer than a week': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'lower estrogen levels': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'worsening premenstrual syndrome': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'look for changes in hormone levels': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'activation frequency in endocortical compartment': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'number of participants with absolute reduction of 4 in mean number of moderate and severe vms per day': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'average age for menopause in the united states': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'over-the-counter, water-based vaginal lubricant': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'hormone therapy for prevention of chronic conditions': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'indian postmenopausal women with osteoporosis': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'individualized homeopathic treatment': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'same as natural hormones': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'sleep problems index ii': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'quality of sexual life': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'women with medical reasons to avoid estrogen': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'other types of exercise': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'decline in cognitive processing': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'total radius bmd': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'bone mineral density of total hip': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'bladder issues': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'korean postmenopausal women with osteoporosis': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'yoga, tai chi, or meditation': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'changing what you eat': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'hot flash-related daily interference scale': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'production of myeloid adipocyte progenitors': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'trochanter areal bmd': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'concerns about heart disease, osteoporosis, and symptoms of menopause': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'number of participants with mean percent reduction of 100% in the mean frequency of moderate and severe vms': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'mood issues': {'CUI': None, 'preferred_name': None, 'semantic_source': None},
#  'sweating followed by shivering': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'mid- to late 40s': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'red blotches on the chest and arms': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'mood swings and hot flashes': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'vulvar and vaginal atrophy': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'american association of clinical endocrinologists': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'changes in sex life': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'bone mass changes': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'low levels of estrogen and progesterone': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'cortical thickness at the distal radius': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'change from baseline in serum carboxyterminal cross-linking telopeptide of type i collagen': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'cumulative incidence of thyroid disorders- goitre': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'elastic fiber synthesis or degradation': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'cumulative incidence of cardiac disorders': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'peri- and postmenopausal women': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'estrogen feedback on luteinizing hormone': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'symptoms ease up or disappear': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'menopausal breast cancer survivors': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'alzheimer’s disease': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'u.s. preventive services task force': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'female sexual function index domain score - satisfaction': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'sexual intercourse uncomfortable': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'thermogenic response of brown adipose tissue': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'more severe menopausal symptoms': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'bone mineral density at the total hip': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'estimated strength at the total hip': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'earlier menopause': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'urinary n-telopeptides/creatinine ratio': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'suppression of ovarian hormones': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'serum carboxyterminal cross-linking telopeptide of type i collagen': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  '12 months without bleeding': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'medications, exercises, and other strategies': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'novel menopause hormone therapy': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'cessation of periods for 12 months': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'asian women': {'CUI': None, 'preferred_name': None, 'semantic_source': None},
#  'endometrial protection': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'japanese women with postmenopausal osteoporosis': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'frequency of hot flushes': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'mean percent reduction of moderate and severe vms': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'night-time awakenings secondary to hot flushes': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'non-hormonal treatment for hot flashes': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'natural part of aging': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'bone mineral density at lumbar spine': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'experimental sleep fragmentation': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'total hip areal bmd': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'body fat gain': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'loss of bone density': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'change from baseline in serum osteocalcin': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'korean women with postmenopausal osteoporosis': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'male menopause': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'change in bone mineral density of axial lumbar spine': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'small cuts or tears during sex': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'femoral neck areal bmd': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'mean lumbar spine bmd': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'no longer become pregnant': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'cutting back on spicy foods': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'enhanced mitochondrial function in females': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'progestogenic symptoms': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'menopause transition': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'number of participants with absolute reduction of 3 in mean number of moderate and severe vms per day': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'vaginal cuts or tears': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'mk-6913': {'CUI': None, 'preferred_name': None, 'semantic_source': None},
#  'custom-mixed bioidentical hormones': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'women aged 45 to 55': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'effect on breast cancer': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'number of participants with mean percent reduction of 70% in the mean frequency of mild, moderate, and severe vms': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'changing estrogen levels': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'bone mineral density at femoral neck': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'topical hormone therapy': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'female sexual function index domain score - lubrication': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'conventional hormone therapy': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'hormone therapy discontinuation': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'poorer verbal memory': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'uncomfortable or painful sex': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'flushing of the face and neck': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'msflash network': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'effect on colorectal cancer': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'look for bone loss related to osteoporosis': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'total body areal bmd': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'association of vms with hrqol': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'menopausal transition': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'estrogen alone hormone therapy': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'low risk for stroke, heart disease, blood clots, or breast cancer': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'emotional changes during menopause': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'oral daily administration': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'women with a uterus': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'estrogen and sometimes progesterone': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'bone mineral density at the femoral neck': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'reproductive cycle slowing': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'estimate of bone strength of hip': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'estrogen creams, tablets, or rings': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'average daily hot flushes severity score': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'number of participants with absolute reduction of 2 in mean number of mild, moderate and severe vms per day': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'structural and functional vascular changes': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'volumetric bone mineral density of hip': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'areal bmd at the femoral neck': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'female sexual function index domain score - pain': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'cumulative amenorrhea': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'nonhormonal treatments': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'whi observational study': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'veteran-focused tool': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'perceived hot flash interference': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'one year after final menstrual period': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'va women’s clinics': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'abaloparatide transdermal': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'younger women with prior hysterectomy': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'number of participants with mean percent reduction of 100% in the mean frequency of mild, moderate, and severe vms': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  '12 consecutive months without a menstrual period': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'glucocorticoid-induced osteoporosis': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'postmenopausal women with low bone density': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'total number of hot flushes': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'neural reward system': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'perimenopausal women': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'patient decision aid': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'severity of moderate and severe hot flushes': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'regular height measurements': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'bothersomeness of hot flashes': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'nonvertebral fractures': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'severe liver injury': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'total hip t-score': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'estrogen therapy risks': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'cortical bone mineral density': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'mean frequency of moderate and severe vms': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'vaginal superficial cells': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'new moderate and/or severe vertebral fractures': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'consuming fewer calories': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'feeling worthless or guilty': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'excess belly fat': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'tissue selective estrogen complex': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'sex uncomfortable or painful': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'preserving bone mass': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'soybeans, chickpeas, lentils, flaxseed, grains, beans, fruits, vegetables': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'menstrual periods that occur less often and eventually stop': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'hypnotherapy for improving sleep': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'multiple chronic pain diagnoses': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'bone mineral density of femoral neck': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'effect on heart disease': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'new vertebral fracture': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'loss of fertility': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'metabolic biomarkers of body fat gain': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'greene climacteric scale': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'effects of timely menopausal hormone therapy': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'over-the-counter vaginal moisturizer': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'number of participants with absolute reduction of 5 in mean number of moderate and severe vms per day': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'serum c-terminal propeptide of type 1 collagen': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'serum c-telopeptides of type 1 collagen': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'lumbar spine bone loss': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'kronos early estrogen prevention study': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'neuropeptide treatment': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'hot flash score of mild, moderate, and severe vms': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'effects of acupuncture on hot flashes': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'bonviva/boniva': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'scientific discoveries': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'non-hormonal medicines': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'serum type-1 c-telopeptide': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'feel stressed or irritable': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'serum procollagen type i n propeptideserum': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'self-management of menopause symptoms': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'mean severity of mild, moderate, and severe vms': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'thicker arterial walls': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'diet low in fat and high in fruits, vegetables, and grains': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'frequency of moderate and severe hot flushes': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'shifts in hormones': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'hormone level variation': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'abnormal ovarian formation': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'urinary n-telopeptides of type i collagen/creatinine ratio': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'bone mineral density at total hip': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'more serious health issue': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'younger age at menopause': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'vaginal tissues to be thinner or drier': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'surgical removal of both ovaries': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'brain structure, connectivity, and energy process': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  "change from baseline in greene's scale": {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'mild menopause symptoms': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  '18 fdg uptake at the hypothalamus': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'change in plasma c-terminal telopeptide of collagen 1': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'certain health problems': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'community prevention study': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'sudden feeling of heat': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'postmenopausal women with osteopenia': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'decreased health-related quality of life': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'elastic fiber number and morphology': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'postmenopausal women with osteoporosis': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'volumetric bone mineral density of lumbar spine': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'bone mineral density of the total hip': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'many years after menopause': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'female sexual function index domain score - arousal': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'glucose and lipid homeostasis': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'postmenopausal dyspareunia': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'study of women’s health across the nation': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'changes in the lining of the vagina': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'leeds sleep evaluation questionnaire domain scores': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'vaginal dryness or irritation': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'new multiple vertebral fractures': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'cumulative incidence of all malignancies': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'vaginal muscularis thickness': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'number of participants with mean percent reduction of 70% in the mean frequency of moderate and severe vms': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'trochanter bone mineral density': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'sleep problems index i': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'over-the-counter gel': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'entry dyspareunia': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'vaginal wall composition': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'vulvar and/or vaginal itching or irritation': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'percent change in bone mineral density at the lumbar spine': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'multiple new or worsening vertebral fractures': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'natural body change': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'more benefit and less risk during menopausal transition': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'calcium usage': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'number of participants with mean percent reduction of 90% in the mean frequency of mild, moderate, and severe vms': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'end of reproductive years': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'estrogen plus progestin hormone therapy': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'final menstrual period': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'number of participants with absolute reduction of 2 in mean number of moderate and severe vms per day': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'msbrain ii': {'CUI': None, 'preferred_name': None, 'semantic_source': None},
#  'psychotherapy/talk therapy/counseling': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None},
#  'major nonvertebral fractures': {'CUI': None,
#   'preferred_name': None,
#   'semantic_source': None}}

# %%
standardized = []

for t in cleaned_triples:
    head = t["head"]
    tail = t["tail"]

    head_map = umls_map.get(head, {})
    tail_map = umls_map.get(tail, {})

    standardized.append({
        "head": head_map.get("preferred_name") or head,
        "head_cui": head_map.get("CUI"),
        "head_semantic_source": head_map.get("semantic_source"),

        "relation": t["relation"],

        "tail": tail_map.get("preferred_name") or tail,
        "tail_cui": tail_map.get("CUI"),
        "tail_semantic_source": tail_map.get("semantic_source"),

        "head_type": t.get("head_type"),
        "tail_type": t.get("tail_type")
    })

# %%
standardized
# Out:
# [{'head': 'Bonviva',
#   'head_cui': 'C0918018',
#   'head_semantic_source': 'MSH',
#   'relation': 'treats',
#   'tail': 'Osteoporosis, Postmenopausal',
#   'tail_cui': 'C0029458',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'medication',
#   'tail_type': 'condition'},
#  {'head': 'vitamin D',
#   'head_cui': 'C0042866',
#   'head_semantic_source': 'MTH',
#   'relation': 'supplementation_with',
#   'tail': 'Osteoporosis, Postmenopausal',
#   'tail_cui': 'C0029458',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'supplement',
#   'tail_type': 'condition'},
#  {'head': 'calcium',
#   'head_cui': 'C0006675',
#   'head_semantic_source': 'MTH',
#   'relation': 'supplementation_with',
#   'tail': 'Osteoporosis, Postmenopausal',
#   'tail_cui': 'C0029458',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'supplement',
#   'tail_type': 'condition'},
#  {'head': 'Bonviva',
#   'head_cui': 'C0918018',
#   'head_semantic_source': 'MSH',
#   'relation': 'improves',
#   'tail': 'Bone Mineral Density Test',
#   'tail_cui': 'C0177804',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'medication',
#   'tail_type': 'biomarker'},
#  {'head': 'Bonviva',
#   'head_cui': 'C0918018',
#   'head_semantic_source': 'MSH',
#   'relation': 'treats',
#   'tail': 'Osteoporosis, Postmenopausal',
#   'tail_cui': 'C0029458',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'medication',
#   'tail_type': 'condition'},
#  {'head': 'intravenous administration',
#   'head_cui': 'C0013125',
#   'head_semantic_source': 'MTH',
#   'relation': 'compared_to',
#   'tail': 'oral daily administration',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'intervention',
#   'tail_type': 'intervention'},
#  {'head': 'vitamin D',
#   'head_cui': 'C0042866',
#   'head_semantic_source': 'MTH',
#   'relation': 'supplementation_with',
#   'tail': 'Osteoporosis, Postmenopausal',
#   'tail_cui': 'C0029458',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'supplement',
#   'tail_type': 'condition'},
#  {'head': 'calcium',
#   'head_cui': 'C0006675',
#   'head_semantic_source': 'MTH',
#   'relation': 'supplementation_with',
#   'tail': 'Osteoporosis, Postmenopausal',
#   'tail_cui': 'C0029458',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'supplement',
#   'tail_type': 'condition'},
#  {'head': 'Bonviva',
#   'head_cui': 'C0918018',
#   'head_semantic_source': 'MSH',
#   'relation': 'affects',
#   'tail': 'Increased bone mineral density of lumbar spine',
#   'tail_cui': 'C3806981',
#   'tail_semantic_source': 'OMIM',
#   'head_type': 'medication',
#   'tail_type': 'biomarker'},
#  {'head': 'Increased bone mineral density of lumbar spine',
#   'head_cui': 'C3806981',
#   'head_semantic_source': 'OMIM',
#   'relation': 'outcome_of',
#   'tail': 'bonviva treatment',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'biomarker',
#   'tail_type': 'treatment'},
#  {'head': 'AMG 162',
#   'head_cui': 'C1530450',
#   'head_semantic_source': 'MSH',
#   'relation': 'prevents',
#   'tail': 'lumbar spine bone loss',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'condition'},
#  {'head': 'AMG 162',
#   'head_cui': 'C1530450',
#   'head_semantic_source': 'MSH',
#   'relation': 'affects',
#   'tail': 'Increased bone mineral density of lumbar spine',
#   'tail_cui': 'C3806981',
#   'tail_semantic_source': 'OMIM',
#   'head_type': 'treatment',
#   'tail_type': 'biomarker'},
#  {'head': 'postmenopausal women with osteopenia',
#   'head_cui': None,
#   'head_semantic_source': None,
#   'relation': 'experiences',
#   'tail': 'lumbar spine bone loss',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'population',
#   'tail_type': 'condition'},
#  {'head': 'Increased bone mineral density of lumbar spine',
#   'head_cui': 'C3806981',
#   'head_semantic_source': 'OMIM',
#   'relation': 'measured_by',
#   'tail': 'percent change from baseline at month 24',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'biomarker',
#   'tail_type': 'outcome'},
#  {'head': 'Bonviva',
#   'head_cui': 'C0918018',
#   'head_semantic_source': 'MSH',
#   'relation': 'treats',
#   'tail': 'Osteopenia',
#   'tail_cui': 'C0029453',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'treatment',
#   'tail_type': 'condition'},
#  {'head': 'Bonviva',
#   'head_cui': 'C0918018',
#   'head_semantic_source': 'MSH',
#   'relation': 'increases',
#   'tail': 'Increased bone mineral density of lumbar spine',
#   'tail_cui': 'C3806981',
#   'tail_semantic_source': 'OMIM',
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'menatetrenone',
#   'head_cui': 'C0065936',
#   'head_semantic_source': 'RXNORM',
#   'relation': 'treats',
#   'tail': 'Osteoporosis, Postmenopausal',
#   'tail_cui': 'C0029458',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'treatment',
#   'tail_type': 'condition'},
#  {'head': 'menatetrenone',
#   'head_cui': 'C0065936',
#   'head_semantic_source': 'RXNORM',
#   'relation': 'affects',
#   'tail': 'Osteocalcin',
#   'tail_cui': 'C0029419',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'treatment',
#   'tail_type': 'biomarker'},
#  {'head': 'menatetrenone',
#   'head_cui': 'C0065936',
#   'head_semantic_source': 'RXNORM',
#   'relation': 'affects',
#   'tail': 'Measurement of undercarboxylated osteocalcin',
#   'tail_cui': 'C2316184',
#   'tail_semantic_source': 'SNOMEDCT_US',
#   'head_type': 'treatment',
#   'tail_type': 'biomarker'},
#  {'head': 'menatetrenone',
#   'head_cui': 'C0065936',
#   'head_semantic_source': 'RXNORM',
#   'relation': 'affects',
#   'tail': 'undercarboxylated osteocalcin/osteocalcin ratio',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'biomarker'},
#  {'head': 'alfacalcidol',
#   'head_cui': 'C0044410',
#   'head_semantic_source': 'MTH',
#   'relation': 'compared_with',
#   'tail': 'menatetrenone',
#   'tail_cui': 'C0065936',
#   'tail_semantic_source': 'RXNORM',
#   'head_type': 'treatment',
#   'tail_type': 'treatment'},
#  {'head': 'levonorgestrel Intrauterine System',
#   'head_cui': 'C4293596',
#   'head_semantic_source': 'RXNORM',
#   'relation': 'used for',
#   'tail': 'Uses contraception (finding)',
#   'tail_cui': 'C4546343',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'treatment',
#   'tail_type': 'intervention'},
#  {'head': 'levonorgestrel Intrauterine System',
#   'head_cui': 'C4293596',
#   'head_semantic_source': 'RXNORM',
#   'relation': 'used for',
#   'tail': 'endometrial protection',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'intervention'},
#  {'head': 'Hormone replacement therapy',
#   'head_cui': 'C0282402',
#   'head_semantic_source': 'MTH',
#   'relation': 'includes',
#   'tail': 'levonorgestrel Intrauterine System',
#   'tail_cui': 'C4293596',
#   'tail_semantic_source': 'RXNORM',
#   'head_type': 'treatment',
#   'tail_type': 'treatment'},
#  {'head': 'Menopausal and other perimenopausal disorders due to naturally occurring (age-related) menopause and perimenopause',
#   'head_cui': 'C2977266',
#   'head_semantic_source': 'ICD10CM',
#   'relation': 'associated with',
#   'tail': 'endometrial protection',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'population',
#   'tail_type': 'intervention'},
#  {'head': 'Menopausal and other perimenopausal disorders due to naturally occurring (age-related) menopause and perimenopause',
#   'head_cui': 'C2977266',
#   'head_semantic_source': 'ICD10CM',
#   'relation': 'associated with',
#   'tail': 'Climacteric discomfort',
#   'tail_cui': 'C1306878',
#   'tail_semantic_source': 'MDR',
#   'head_type': 'population',
#   'tail_type': 'symptom'},
#  {'head': 'Climacteric discomfort',
#   'head_cui': 'C1306878',
#   'head_semantic_source': 'MDR',
#   'relation': 'includes',
#   'tail': 'Hot flushes',
#   'tail_cui': 'C0600142',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'symptom',
#   'tail_type': 'symptom'},
#  {'head': 'Climacteric discomfort',
#   'head_cui': 'C1306878',
#   'head_semantic_source': 'MDR',
#   'relation': 'includes',
#   'tail': 'Sweating during paroxysmal hypertension episodes',
#   'tail_cui': 'C5563387',
#   'tail_semantic_source': 'OMIM',
#   'head_type': 'symptom',
#   'tail_type': 'symptom'},
#  {'head': 'Climacteric discomfort',
#   'head_cui': 'C1306878',
#   'head_semantic_source': 'MDR',
#   'relation': 'includes',
#   'tail': 'Vaginal dryness',
#   'tail_cui': 'C0241633',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'symptom',
#   'tail_type': 'symptom'},
#  {'head': 'Climacteric discomfort',
#   'head_cui': 'C1306878',
#   'head_semantic_source': 'MDR',
#   'relation': 'includes',
#   'tail': 'Dyssomnias',
#   'tail_cui': 'C0700201',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'symptom',
#   'tail_type': 'symptom'},
#  {'head': 'Climacteric discomfort',
#   'head_cui': 'C1306878',
#   'head_semantic_source': 'MDR',
#   'relation': 'includes',
#   'tail': 'Irritability - emotion',
#   'tail_cui': 'C2700617',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'symptom',
#   'tail_type': 'symptom'},
#  {'head': 'progestogenic symptoms',
#   'head_cui': None,
#   'head_semantic_source': None,
#   'relation': 'includes',
#   'tail': 'Headache',
#   'tail_cui': 'C0018681',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'symptom',
#   'tail_type': 'symptom'},
#  {'head': 'progestogenic symptoms',
#   'head_cui': None,
#   'head_semantic_source': None,
#   'relation': 'includes',
#   'tail': 'Chronic depressive mood',
#   'tail_cui': 'C0856960',
#   'tail_semantic_source': 'MDR',
#   'head_type': 'symptom',
#   'tail_type': 'symptom'},
#  {'head': 'progestogenic symptoms',
#   'head_cui': None,
#   'head_semantic_source': None,
#   'relation': 'includes',
#   'tail': 'acne or greasy skin',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'symptom',
#   'tail_type': 'symptom'},
#  {'head': 'progestogenic symptoms',
#   'head_cui': None,
#   'head_semantic_source': None,
#   'relation': 'includes',
#   'tail': 'Nausea',
#   'tail_cui': 'C0027497',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'symptom',
#   'tail_type': 'symptom'},
#  {'head': 'progestogenic symptoms',
#   'head_cui': None,
#   'head_semantic_source': None,
#   'relation': 'includes',
#   'tail': 'Decreased Libido',
#   'tail_cui': 'C0011124',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'symptom',
#   'tail_type': 'symptom'},
#  {'head': 'progestogenic symptoms',
#   'head_cui': None,
#   'head_semantic_source': None,
#   'relation': 'includes',
#   'tail': 'Greasy hair',
#   'tail_cui': 'C0277961',
#   'tail_semantic_source': 'SNOMEDCT_US',
#   'head_type': 'symptom',
#   'tail_type': 'symptom'},
#  {'head': 'ibandronate',
#   'head_cui': 'C0379199',
#   'head_semantic_source': 'MTH',
#   'relation': 'treats',
#   'tail': 'Osteoporosis',
#   'tail_cui': 'C0029456',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'medication',
#   'tail_type': 'condition'},
#  {'head': 'ibandronate',
#   'head_cui': 'C0379199',
#   'head_semantic_source': 'MTH',
#   'relation': 'suppresses',
#   'tail': 'serum c-terminal telopeptide of type 1 collagen',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'medication',
#   'tail_type': 'biomarker'},
#  {'head': 'vitamin D',
#   'head_cui': 'C0042866',
#   'head_semantic_source': 'MTH',
#   'relation': 'used_with',
#   'tail': 'ibandronate',
#   'tail_cui': 'C0379199',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'supplement',
#   'tail_type': 'medication'},
#  {'head': 'calcium',
#   'head_cui': 'C0006675',
#   'head_semantic_source': 'MTH',
#   'relation': 'used_with',
#   'tail': 'ibandronate',
#   'tail_cui': 'C0379199',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'supplement',
#   'tail_type': 'medication'},
#  {'head': 'serum c-terminal telopeptide of type 1 collagen',
#   'head_cui': None,
#   'head_semantic_source': None,
#   'relation': 'associated_with',
#   'tail': 'Bone Resorption',
#   'tail_cui': 'C0005974',
#   'tail_semantic_source': 'MSH',
#   'head_type': 'biomarker',
#   'tail_type': 'biological process'},
#  {'head': 'Osteoporosis, Postmenopausal',
#   'head_cui': 'C0029458',
#   'head_semantic_source': 'MTH',
#   'relation': 'treated_with',
#   'tail': 'ibandronate',
#   'tail_cui': 'C0379199',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'medication'},
#  {'head': 'Osteoporosis, Postmenopausal',
#   'head_cui': 'C0029458',
#   'head_semantic_source': 'MTH',
#   'relation': 'treated_with',
#   'tail': 'risedronate',
#   'tail_cui': 'C0246719',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'medication'},
#  {'head': 'ibandronate',
#   'head_cui': 'C0379199',
#   'head_semantic_source': 'MTH',
#   'relation': 'preferred_over',
#   'tail': 'risedronate',
#   'tail_cui': 'C0246719',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'medication',
#   'tail_type': 'medication'},
#  {'head': 'alendronate',
#   'head_cui': 'C0102118',
#   'head_semantic_source': 'MTH',
#   'relation': 'transitioned_to',
#   'tail': 'denosumab',
#   'tail_cui': 'C1690432',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'treatment',
#   'tail_type': 'treatment'},
#  {'head': 'denosumab',
#   'head_cui': 'C1690432',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'Increased bone mineral density of lumbar spine',
#   'tail_cui': 'C3806981',
#   'tail_semantic_source': 'OMIM',
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'denosumab',
#   'head_cui': 'C1690432',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'C-telopeptide serum',
#   'tail_cui': 'C1868870',
#   'tail_semantic_source': 'MDR',
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'denosumab',
#   'head_cui': 'C1690432',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'total hip bone mineral density',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'ibandronate',
#   'head_cui': 'C0379199',
#   'head_semantic_source': 'MTH',
#   'relation': 'is_preferred_over',
#   'tail': 'risedronate',
#   'tail_cui': 'C0246719',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'medication',
#   'tail_type': 'medication'},
#  {'head': 'ibandronate',
#   'head_cui': 'C0379199',
#   'head_semantic_source': 'MTH',
#   'relation': 'has_dosing_frequency',
#   'tail': 'Once monthly',
#   'tail_cui': 'C0585302',
#   'tail_semantic_source': 'SNOMEDCT_US',
#   'head_type': 'medication',
#   'tail_type': 'treatment'},
#  {'head': 'risedronate',
#   'head_cui': 'C0246719',
#   'head_semantic_source': 'MTH',
#   'relation': 'has_dosing_frequency',
#   'tail': 'About Once Weekly',
#   'tail_cui': 'C3900130',
#   'tail_semantic_source': 'NCI',
#   'head_type': 'medication',
#   'tail_type': 'treatment'},
#  {'head': 'korean women with postmenopausal osteoporosis',
#   'head_cui': None,
#   'head_semantic_source': None,
#   'relation': 'receives',
#   'tail': 'ibandronate',
#   'tail_cui': 'C0379199',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'population',
#   'tail_type': 'medication'},
#  {'head': 'korean women with postmenopausal osteoporosis',
#   'head_cui': None,
#   'head_semantic_source': None,
#   'relation': 'receives',
#   'tail': 'risedronate',
#   'tail_cui': 'C0246719',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'population',
#   'tail_type': 'medication'},
#  {'head': 'Estrogen measurement',
#   'head_cui': 'C0202006',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'Hypothalamic structure',
#   'tail_cui': 'C0020663',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'biomarker',
#   'tail_type': 'condition'},
#  {'head': 'Estrogen measurement',
#   'head_cui': 'C0202006',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'Pituitary Diseases',
#   'tail_cui': 'C0032002',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'biomarker',
#   'tail_type': 'condition'},
#  {'head': 'Hypothalamic structure',
#   'head_cui': 'C0020663',
#   'head_semantic_source': 'MTH',
#   'relation': 'secretes',
#   'tail': 'gonadorelin',
#   'tail_cui': 'C0023610',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'biomarker'},
#  {'head': 'gonadorelin',
#   'head_cui': 'C0023610',
#   'head_semantic_source': 'MTH',
#   'relation': 'signals',
#   'tail': 'Pituitary Diseases',
#   'tail_cui': 'C0032002',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'biomarker',
#   'tail_type': 'condition'},
#  {'head': 'Pituitary Diseases',
#   'head_cui': 'C0032002',
#   'head_semantic_source': 'MTH',
#   'relation': 'secretes',
#   'tail': 'luteinizing hormone',
#   'tail_cui': 'C0023607',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'biomarker'},
#  {'head': 'Pituitary Diseases',
#   'head_cui': 'C0032002',
#   'head_semantic_source': 'MTH',
#   'relation': 'secretes',
#   'tail': 'follicle stimulating hormone',
#   'tail_cui': 'C0733758',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'biomarker'},
#  {'head': 'luteinizing hormone',
#   'head_cui': 'C0023607',
#   'head_semantic_source': 'MTH',
#   'relation': 'acts_on',
#   'tail': 'Both ovaries',
#   'tail_cui': 'C0227898',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'biomarker',
#   'tail_type': 'condition'},
#  {'head': 'follicle stimulating hormone',
#   'head_cui': 'C0733758',
#   'head_semantic_source': 'MTH',
#   'relation': 'acts_on',
#   'tail': 'Both ovaries',
#   'tail_cui': 'C0227898',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'biomarker',
#   'tail_type': 'condition'},
#  {'head': 'Both ovaries',
#   'head_cui': 'C0227898',
#   'head_semantic_source': 'MTH',
#   'relation': 'produce',
#   'tail': 'Estrogen measurement',
#   'tail_cui': 'C0202006',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'biomarker'},
#  {'head': 'Both ovaries',
#   'head_cui': 'C0227898',
#   'head_semantic_source': 'MTH',
#   'relation': 'produce',
#   'tail': 'progesterone',
#   'tail_cui': 'C0033308',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'biomarker'},
#  {'head': 'Estrogen measurement',
#   'head_cui': 'C0202006',
#   'head_semantic_source': 'MTH',
#   'relation': 'modulates',
#   'tail': 'luteinizing hormone',
#   'tail_cui': 'C0023607',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'biomarker',
#   'tail_type': 'biomarker'},
#  {'head': 'Estrogen measurement',
#   'head_cui': 'C0202006',
#   'head_semantic_source': 'MTH',
#   'relation': 'modulates',
#   'tail': 'follicle stimulating hormone',
#   'tail_cui': 'C0733758',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'biomarker',
#   'tail_type': 'biomarker'},
#  {'head': 'Aging',
#   'head_cui': 'C0001811',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'estrogen feedback on luteinizing hormone',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'condition',
#   'tail_type': 'outcome'},
#  {'head': 'Estrogen measurement',
#   'head_cui': 'C0202006',
#   'head_semantic_source': 'MTH',
#   'relation': 'influences',
#   'tail': '18 fdg uptake at the hypothalamus',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'biomarker',
#   'tail_type': 'outcome'},
#  {'head': 'Estrogen measurement',
#   'head_cui': 'C0202006',
#   'head_semantic_source': 'MTH',
#   'relation': 'influences',
#   'tail': '18 fdg uptake at the pituitary',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'biomarker',
#   'tail_type': 'outcome'},
#  {'head': 'odanacatib',
#   'head_cui': 'C2351970',
#   'head_semantic_source': 'MSH',
#   'relation': 'treats',
#   'tail': 'Osteoporosis',
#   'tail_cui': 'C0029456',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'medication',
#   'tail_type': 'condition'},
#  {'head': 'odanacatib',
#   'head_cui': 'C2351970',
#   'head_semantic_source': 'MSH',
#   'relation': 'reduces_risk_of',
#   'tail': 'Fracture',
#   'tail_cui': 'C0016658',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'medication',
#   'tail_type': 'outcome'},
#  {'head': 'odanacatib',
#   'head_cui': 'C2351970',
#   'head_semantic_source': 'MSH',
#   'relation': 'increases',
#   'tail': 'Bone Mineral Density Test',
#   'tail_cui': 'C0177804',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'medication',
#   'tail_type': 'biomarker'},
#  {'head': 'odanacatib',
#   'head_cui': 'C2351970',
#   'head_semantic_source': 'MSH',
#   'relation': 'reduces',
#   'tail': 'Bone Specific Alkaline Phosphatase Measurement',
#   'tail_cui': 'C2984961',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'medication',
#   'tail_type': 'biomarker'},
#  {'head': 'odanacatib',
#   'head_cui': 'C2351970',
#   'head_semantic_source': 'MSH',
#   'relation': 'reduces',
#   'tail': 'n-terminal propeptide of type 1 collagen',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'medication',
#   'tail_type': 'biomarker'},
#  {'head': 'odanacatib',
#   'head_cui': 'C2351970',
#   'head_semantic_source': 'MSH',
#   'relation': 'reduces',
#   'tail': 'serum c-telopeptides of type i collagen',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'medication',
#   'tail_type': 'biomarker'},
#  {'head': 'odanacatib',
#   'head_cui': 'C2351970',
#   'head_semantic_source': 'MSH',
#   'relation': 'reduces',
#   'tail': 'urinary n-telopeptides of type i collagen/creatinine ratio',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'medication',
#   'tail_type': 'biomarker'},
#  {'head': 'Obtain multiple measurements of endometrial thickness from various angles for women presenting with postmenopausal bleeding',
#   'head_cui': 'C4714592',
#   'head_semantic_source': 'NIC',
#   'relation': 'has_condition',
#   'tail': 'Osteoporosis',
#   'tail_cui': 'C0029456',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'population',
#   'tail_type': 'condition'},
#  {'head': 'Esmirtazapine',
#   'head_cui': 'C2700014',
#   'head_semantic_source': 'MSH',
#   'relation': 'treats',
#   'tail': 'Vasomotor menopausal symptoms',
#   'tail_cui': 'C5442256',
#   'tail_semantic_source': 'MDR',
#   'head_type': 'treatment',
#   'tail_type': 'symptom'},
#  {'head': 'Esmirtazapine',
#   'head_cui': 'C2700014',
#   'head_semantic_source': 'MSH',
#   'relation': 'reduces',
#   'tail': 'frequency of hot flushes',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'Esmirtazapine',
#   'head_cui': 'C2700014',
#   'head_semantic_source': 'MSH',
#   'relation': 'reduces',
#   'tail': 'severity of hot flushes',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'Vasomotor menopausal symptoms',
#   'head_cui': 'C5442256',
#   'head_semantic_source': 'MDR',
#   'relation': 'associated_with',
#   'tail': 'Menopause',
#   'tail_cui': 'C0025320',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'symptom',
#   'tail_type': 'condition'},
#  {'head': 'Bonviva',
#   'head_cui': 'C0918018',
#   'head_semantic_source': 'MSH',
#   'relation': 'prevents',
#   'tail': 'glucocorticoid-induced osteoporosis',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'condition'},
#  {'head': 'Bonviva',
#   'head_cui': 'C0918018',
#   'head_semantic_source': 'MSH',
#   'relation': 'affects',
#   'tail': 'bone turnover markers',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'biomarker'},
#  {'head': 'Bonviva',
#   'head_cui': 'C0918018',
#   'head_semantic_source': 'MSH',
#   'relation': 'increases',
#   'tail': 'Increased bone mineral density of lumbar spine',
#   'tail_cui': 'C3806981',
#   'tail_semantic_source': 'OMIM',
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'Bonviva',
#   'head_cui': 'C0918018',
#   'head_semantic_source': 'MSH',
#   'relation': 'increases',
#   'tail': 'total hip bone mineral density',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'vitamin D',
#   'head_cui': 'C0042866',
#   'head_semantic_source': 'MTH',
#   'relation': 'used_with',
#   'tail': 'Bonviva',
#   'tail_cui': 'C0918018',
#   'tail_semantic_source': 'MSH',
#   'head_type': 'supplement',
#   'tail_type': 'treatment'},
#  {'head': 'calcium',
#   'head_cui': 'C0006675',
#   'head_semantic_source': 'MTH',
#   'relation': 'used_with',
#   'tail': 'Bonviva',
#   'tail_cui': 'C0918018',
#   'tail_semantic_source': 'MSH',
#   'head_type': 'supplement',
#   'tail_type': 'treatment'},
#  {'head': 'post-menopausal women',
#   'head_cui': None,
#   'head_semantic_source': None,
#   'relation': 'target_of',
#   'tail': 'Bonviva',
#   'tail_cui': 'C0918018',
#   'tail_semantic_source': 'MSH',
#   'head_type': 'population',
#   'tail_type': 'treatment'},
#  {'head': 'teriparatide',
#   'head_cui': 'C0070093',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'Skeletal bone',
#   'tail_cui': 'C0262950',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'teriparatide',
#   'head_cui': 'C0070093',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'areal bmd at the femoral neck',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'teriparatide',
#   'head_cui': 'C0070093',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'areal bmd at the lumbar spine',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'teriparatide',
#   'head_cui': 'C0070093',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'areal bmd at ⅓ distal radius',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'teriparatide',
#   'head_cui': 'C0070093',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'serum carboxyterminal cross-linking telopeptide of type i collagen',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'biomarker'},
#  {'head': 'teriparatide',
#   'head_cui': 'C0070093',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'Serum procollagen type I N-terminal propeptide increased',
#   'tail_cui': 'C1610612',
#   'tail_semantic_source': 'MDR',
#   'head_type': 'treatment',
#   'tail_type': 'biomarker'},
#  {'head': 'teriparatide',
#   'head_cui': 'C0070093',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'volumetric bone mineral density of hip',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'teriparatide',
#   'head_cui': 'C0070093',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'volumetric bone mineral density of lumbar spine',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'teriparatide',
#   'head_cui': 'C0070093',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'estimate of bone strength of hip',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'teriparatide',
#   'head_cui': 'C0070093',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'estimate of bone strength of lumbar spine',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'Obtain multiple measurements of endometrial thickness from various angles for women presenting with postmenopausal bleeding',
#   'head_cui': 'C4714592',
#   'head_semantic_source': 'NIC',
#   'relation': 'has_condition',
#   'tail': 'Osteoporosis',
#   'tail_cui': 'C0029456',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'population',
#   'tail_type': 'condition'},
#  {'head': 'Esmirtazapine',
#   'head_cui': 'C2700014',
#   'head_semantic_source': 'MSH',
#   'relation': 'treats',
#   'tail': 'Vasomotor menopausal symptoms',
#   'tail_cui': 'C5442256',
#   'tail_semantic_source': 'MDR',
#   'head_type': 'treatment',
#   'tail_type': 'symptom'},
#  {'head': 'Vasomotor menopausal symptoms',
#   'head_cui': 'C5442256',
#   'head_semantic_source': 'MDR',
#   'relation': 'associated_with',
#   'tail': 'Menopause',
#   'tail_cui': 'C0025320',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'symptom',
#   'tail_type': 'condition'},
#  {'head': 'Serotonin 5-HT2A Receptor Antagonists',
#   'head_cui': 'C2936524',
#   'head_semantic_source': 'MSH',
#   'relation': 'may_treat',
#   'tail': 'Vasomotor menopausal symptoms',
#   'tail_cui': 'C5442256',
#   'tail_semantic_source': 'MDR',
#   'head_type': 'treatment',
#   'tail_type': 'symptom'},
#  {'head': 'mirtazapine',
#   'head_cui': 'C0049506',
#   'head_semantic_source': 'MTH',
#   'relation': 'blocks',
#   'tail': 'Receptor, Serotonin, 5-HT2A',
#   'tail_cui': 'C0289174',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'treatment',
#   'tail_type': 'biomarker'},
#  {'head': 'mirtazapine',
#   'head_cui': 'C0049506',
#   'head_semantic_source': 'MTH',
#   'relation': 'reduces',
#   'tail': 'Hot flushes',
#   'tail_cui': 'C0600142',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'treatment',
#   'tail_type': 'symptom'},
#  {'head': 'Selective Serotonin Reuptake Inhibitors',
#   'head_cui': 'C0360105',
#   'head_semantic_source': 'MTH',
#   'relation': 'manage',
#   'tail': 'Hot flushes',
#   'tail_cui': 'C0600142',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'treatment',
#   'tail_type': 'symptom'},
#  {'head': 'Esmirtazapine',
#   'head_cui': 'C2700014',
#   'head_semantic_source': 'MSH',
#   'relation': 'shows_superior_efficacy_to',
#   'tail': 'placebo',
#   'tail_cui': 'C1696465',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'treatment',
#   'tail_type': 'treatment'},
#  {'head': 'GSK232802',
#   'head_cui': 'C5432280',
#   'head_semantic_source': 'DRUGBANK',
#   'relation': 'reduces',
#   'tail': 'frequency of vasomotor symptoms',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'GSK232802',
#   'head_cui': 'C5432280',
#   'head_semantic_source': 'DRUGBANK',
#   'relation': 'reduces',
#   'tail': 'severity of vasomotor symptoms',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'Hot flushes',
#   'head_cui': 'C0600142',
#   'head_semantic_source': 'MTH',
#   'relation': 'associated_with',
#   'tail': 'Menopause',
#   'tail_cui': 'C0025320',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'symptom',
#   'tail_type': 'condition'},
#  {'head': 'odanacatib',
#   'head_cui': 'C2351970',
#   'head_semantic_source': 'MSH',
#   'relation': 'increases',
#   'tail': 'Increased bone mineral density of lumbar spine',
#   'tail_cui': 'C3806981',
#   'tail_semantic_source': 'OMIM',
#   'head_type': 'medication',
#   'tail_type': 'outcome'},
#  {'head': 'odanacatib',
#   'head_cui': 'C2351970',
#   'head_semantic_source': 'MSH',
#   'relation': 'increases',
#   'tail': 'femoral neck bone mineral density',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'medication',
#   'tail_type': 'outcome'},
#  {'head': 'odanacatib',
#   'head_cui': 'C2351970',
#   'head_semantic_source': 'MSH',
#   'relation': 'increases',
#   'tail': 'total hip bone mineral density',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'medication',
#   'tail_type': 'outcome'},
#  {'head': 'odanacatib',
#   'head_cui': 'C2351970',
#   'head_semantic_source': 'MSH',
#   'relation': 'increases',
#   'tail': 'trochanter bone mineral density',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'medication',
#   'tail_type': 'outcome'},
#  {'head': 'odanacatib',
#   'head_cui': 'C2351970',
#   'head_semantic_source': 'MSH',
#   'relation': 'decreases',
#   'tail': 'serum bone specific alkaline phosphatase level',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'medication',
#   'tail_type': 'biomarker'},
#  {'head': 'odanacatib',
#   'head_cui': 'C2351970',
#   'head_semantic_source': 'MSH',
#   'relation': 'decreases',
#   'tail': 'serum c-telopeptides of type 1 collagen level',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'medication',
#   'tail_type': 'biomarker'},
#  {'head': 'odanacatib',
#   'head_cui': 'C2351970',
#   'head_semantic_source': 'MSH',
#   'relation': 'decreases',
#   'tail': 'serum n-terminal propeptides of type 1 collagen level',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'medication',
#   'tail_type': 'biomarker'},
#  {'head': 'odanacatib',
#   'head_cui': 'C2351970',
#   'head_semantic_source': 'MSH',
#   'relation': 'decreases',
#   'tail': 'urinary deoxypyridinoline/creatinine ratio',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'medication',
#   'tail_type': 'biomarker'},
#  {'head': 'odanacatib',
#   'head_cui': 'C2351970',
#   'head_semantic_source': 'MSH',
#   'relation': 'decreases',
#   'tail': 'urinary n-telopeptides/creatinine ratio',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'medication',
#   'tail_type': 'biomarker'},
#  {'head': 'vitamin D3',
#   'head_cui': 'C3265062',
#   'head_semantic_source': 'MTH',
#   'relation': 'used_with',
#   'tail': 'odanacatib',
#   'tail_cui': 'C2351970',
#   'tail_semantic_source': 'MSH',
#   'head_type': 'supplement',
#   'tail_type': 'medication'},
#  {'head': 'calcium carbonate',
#   'head_cui': 'C0006681',
#   'head_semantic_source': 'MTH',
#   'relation': 'used_with',
#   'tail': 'odanacatib',
#   'tail_cui': 'C2351970',
#   'tail_semantic_source': 'MSH',
#   'head_type': 'supplement',
#   'tail_type': 'medication'},
#  {'head': 'bazedoxifene / estrogens, conjugated (USP)',
#   'head_cui': 'C3668765',
#   'head_semantic_source': 'RXNORM',
#   'relation': 'treats',
#   'tail': 'Menopausal symptom',
#   'tail_cui': 'C0236075',
#   'tail_semantic_source': 'SNOMEDCT_US',
#   'head_type': 'treatment',
#   'tail_type': 'condition'},
#  {'head': 'bazedoxifene / estrogens, conjugated (USP)',
#   'head_cui': 'C3668765',
#   'head_semantic_source': 'RXNORM',
#   'relation': 'protects',
#   'tail': 'Endometrium',
#   'tail_cui': 'C0014180',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'treatment',
#   'tail_type': 'condition'},
#  {'head': 'bazedoxifene / estrogens, conjugated (USP)',
#   'head_cui': 'C3668765',
#   'head_semantic_source': 'RXNORM',
#   'relation': 'prevents',
#   'tail': 'Osteoporosis, Postmenopausal',
#   'tail_cui': 'C0029458',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'treatment',
#   'tail_type': 'condition'},
#  {'head': 'bazedoxifene / estrogens, conjugated (USP)',
#   'head_cui': 'C3668765',
#   'head_semantic_source': 'RXNORM',
#   'relation': 'improves',
#   'tail': 'Menopause-specific Quality of Life Questionnaire',
#   'tail_cui': 'C5959843',
#   'tail_semantic_source': 'NCI',
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'bazedoxifene / estrogens, conjugated (USP)',
#   'head_cui': 'C3668765',
#   'head_semantic_source': 'RXNORM',
#   'relation': 'increases',
#   'tail': 'Increased bone mineral density of lumbar spine',
#   'tail_cui': 'C3806981',
#   'tail_semantic_source': 'OMIM',
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'bazedoxifene / estrogens, conjugated (USP)',
#   'head_cui': 'C3668765',
#   'head_semantic_source': 'RXNORM',
#   'relation': 'increases',
#   'tail': 'bone mineral density of total hip',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'bazedoxifene / estrogens, conjugated (USP)',
#   'head_cui': 'C3668765',
#   'head_semantic_source': 'RXNORM',
#   'relation': 'affects',
#   'tail': 'bone turnover markers',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'biomarker'},
#  {'head': 'bazedoxifene / estrogens, conjugated (USP)',
#   'head_cui': 'C3668765',
#   'head_semantic_source': 'RXNORM',
#   'relation': 'causes',
#   'tail': 'Tenderness of breast',
#   'tail_cui': 'C0262397',
#   'tail_semantic_source': 'SNOMEDCT_US',
#   'head_type': 'treatment',
#   'tail_type': 'symptom'},
#  {'head': 'bazedoxifene / estrogens, conjugated (USP)',
#   'head_cui': 'C3668765',
#   'head_semantic_source': 'RXNORM',
#   'relation': 'causes',
#   'tail': 'cumulative amenorrhea',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'symptom'},
#  {'head': 'bazedoxifene / estrogens, conjugated (USP)',
#   'head_cui': 'C3668765',
#   'head_semantic_source': 'RXNORM',
#   'relation': 'causes',
#   'tail': 'Uterine hemorrhage',
#   'tail_cui': 'C0042134',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'treatment',
#   'tail_type': 'symptom'},
#  {'head': 'Estrogen measurement',
#   'head_cui': 'C0202006',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'Finding of hormone level',
#   'tail_cui': 'C1287355',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'treatment',
#   'tail_type': 'biomarker'},
#  {'head': 'Estrogen measurement',
#   'head_cui': 'C0202006',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'uterine lining',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'condition'},
#  {'head': 'Estrogen measurement',
#   'head_cui': 'C0202006',
#   'head_semantic_source': 'MTH',
#   'relation': 'has_outcome',
#   'tail': 'proliferative effects',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'denosumab',
#   'head_cui': 'C1690432',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'cortical thickness at the distal radius',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'denosumab',
#   'head_cui': 'C1690432',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'cortical bmd at the distal radius',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'denosumab',
#   'head_cui': 'C1690432',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'total bmd at the distal tibia',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'denosumab',
#   'head_cui': 'C1690432',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'trabecular bmd at the distal tibia',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'denosumab',
#   'head_cui': 'C1690432',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'distal 1/3 radius bmd',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'denosumab',
#   'head_cui': 'C1690432',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'total radius bmd',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'escitalopram',
#   'head_cui': 'C1099456',
#   'head_semantic_source': 'MTH',
#   'relation': 'reduces',
#   'tail': 'Hot flushes',
#   'tail_cui': 'C0600142',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'medication',
#   'tail_type': 'symptom'},
#  {'head': 'escitalopram',
#   'head_cui': 'C1099456',
#   'head_semantic_source': 'MTH',
#   'relation': 'reduces',
#   'tail': 'PRO-CTCAE V1.0 - Hot Flashes Severity',
#   'tail_cui': 'C5706828',
#   'tail_semantic_source': 'NCI',
#   'head_type': 'medication',
#   'tail_type': 'outcome'},
#  {'head': 'escitalopram',
#   'head_cui': 'C1099456',
#   'head_semantic_source': 'MTH',
#   'relation': 'reduces',
#   'tail': 'Bothered by Hot Flashes',
#   'tail_cui': 'C4085327',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'medication',
#   'tail_type': 'outcome'},
#  {'head': 'serotonin',
#   'head_cui': 'C0036751',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'estradiol',
#   'tail_cui': 'C0014912',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'biomarker',
#   'tail_type': 'biomarker'},
#  {'head': 'estradiol',
#   'head_cui': 'C0014912',
#   'head_semantic_source': 'MTH',
#   'relation': 'related_to',
#   'tail': 'Hot flushes',
#   'tail_cui': 'C0600142',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'biomarker',
#   'tail_type': 'symptom'},
#  {'head': 'romosozumab',
#   'head_cui': 'C3661283',
#   'head_semantic_source': 'RXNORM',
#   'relation': 'affects',
#   'tail': 'bone mineral density at the lumbar spine',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'postmenopausal women with low bone density',
#   'head_cui': None,
#   'head_semantic_source': None,
#   'relation': 'has_outcome',
#   'tail': 'percent change in bone mineral density at the lumbar spine',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'population',
#   'tail_type': 'outcome'},
#  {'head': 'teriparatide',
#   'head_cui': 'C0070093',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'bone in postmenopausal osteoporotic women',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'condition'},
#  {'head': 'zoledronic acid',
#   'head_cui': 'C0257685',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'bone in postmenopausal osteoporotic women',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'condition'},
#  {'head': 'teriparatide',
#   'head_cui': 'C0070093',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'activation frequency in cancellous compartment',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'zoledronic acid',
#   'head_cui': 'C0257685',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'activation frequency in cancellous compartment',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'teriparatide',
#   'head_cui': 'C0070093',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'activation frequency in endocortical compartment',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'zoledronic acid',
#   'head_cui': 'C0257685',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'activation frequency in endocortical compartment',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'teriparatide',
#   'head_cui': 'C0070093',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'bone formation rate in cancellous compartment',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'zoledronic acid',
#   'head_cui': 'C0257685',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'bone formation rate in cancellous compartment',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'teriparatide',
#   'head_cui': 'C0070093',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'bone formation rate in endocortical compartment',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'zoledronic acid',
#   'head_cui': 'C0257685',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'bone formation rate in endocortical compartment',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'teriparatide',
#   'head_cui': 'C0070093',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'change from baseline in serum carboxyterminal cross-linking telopeptide of type i collagen',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'zoledronic acid',
#   'head_cui': 'C0257685',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'change from baseline in serum carboxyterminal cross-linking telopeptide of type i collagen',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'teriparatide',
#   'head_cui': 'C0070093',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'change from baseline in serum osteocalcin',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'zoledronic acid',
#   'head_cui': 'C0257685',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'change from baseline in serum osteocalcin',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'teriparatide',
#   'head_cui': 'C0070093',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'change from baseline in serum procollagen type i n-terminal propeptide',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'zoledronic acid',
#   'head_cui': 'C0257685',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'change from baseline in serum procollagen type i n-terminal propeptide',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'denosumab',
#   'head_cui': 'C1690432',
#   'head_semantic_source': 'MTH',
#   'relation': 'increases',
#   'tail': 'femoral neck bone mineral density',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'denosumab',
#   'head_cui': 'C1690432',
#   'head_semantic_source': 'MTH',
#   'relation': 'increases',
#   'tail': 'Increased bone mineral density of lumbar spine',
#   'tail_cui': 'C3806981',
#   'tail_semantic_source': 'OMIM',
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'denosumab',
#   'head_cui': 'C1690432',
#   'head_semantic_source': 'MTH',
#   'relation': 'increases',
#   'tail': 'total hip bone mineral density',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'denosumab',
#   'head_cui': 'C1690432',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'serum type-1 c-telopeptide',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'biomarker'},
#  {'head': 'ibandronate',
#   'head_cui': 'C0379199',
#   'head_semantic_source': 'MTH',
#   'relation': 'increases',
#   'tail': 'femoral neck bone mineral density',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'ibandronate',
#   'head_cui': 'C0379199',
#   'head_semantic_source': 'MTH',
#   'relation': 'increases',
#   'tail': 'Increased bone mineral density of lumbar spine',
#   'tail_cui': 'C3806981',
#   'tail_semantic_source': 'OMIM',
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'ibandronate',
#   'head_cui': 'C0379199',
#   'head_semantic_source': 'MTH',
#   'relation': 'increases',
#   'tail': 'total hip bone mineral density',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'outcome'},
#  {'head': 'ibandronate',
#   'head_cui': 'C0379199',
#   'head_semantic_source': 'MTH',
#   'relation': 'affects',
#   'tail': 'serum type-1 c-telopeptide',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'biomarker'},
#  {'head': 'Obtain multiple measurements of endometrial thickness from various angles for women presenting with postmenopausal bleeding',
#   'head_cui': 'C4714592',
#   'head_semantic_source': 'NIC',
#   'relation': 'treated_with',
#   'tail': 'denosumab',
#   'tail_cui': 'C1690432',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'population',
#   'tail_type': 'treatment'},
#  {'head': 'Obtain multiple measurements of endometrial thickness from various angles for women presenting with postmenopausal bleeding',
#   'head_cui': 'C4714592',
#   'head_semantic_source': 'NIC',
#   'relation': 'treated_with',
#   'tail': 'ibandronate',
#   'tail_cui': 'C0379199',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'population',
#   'tail_type': 'treatment'},
#  {'head': 'salmon calcitonin Nasal Spray',
#   'head_cui': 'C1248993',
#   'head_semantic_source': 'RXNORM',
#   'relation': 'treats',
#   'tail': 'Osteoporosis',
#   'tail_cui': 'C0029456',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'treatment',
#   'tail_type': 'condition'},
#  {'head': 'oral calcitonin',
#   'head_cui': None,
#   'head_semantic_source': None,
#   'relation': 'treats',
#   'tail': 'Osteoporosis',
#   'tail_cui': 'C0029456',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'treatment',
#   'tail_type': 'condition'},
#  {'head': 'Osteoporosis',
#   'head_cui': 'C0029456',
#   'head_semantic_source': 'MTH',
#   'relation': 'characterized_by',
#   'tail': 'loss of bone density',
#   'tail_cui': None,
#   'tail_semantic_source': None,
# ...
#   'relation': 'is_a_stage_of',
#   'tail': 'Menopause',
#   'tail_cui': 'C0025320',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'condition'},
#  {'head': 'Perimenopause',
#   'head_cui': 'C0993589',
#   'head_semantic_source': 'MTH',
#   'relation': 'begins_before',
#   'tail': 'Menopause',
#   'tail_cui': 'C0025320',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'condition'},
#  {'head': 'Perimenopause',
#   'head_cui': 'C0993589',
#   'head_semantic_source': 'MTH',
#   'relation': 'causes',
#   'tail': 'Irregular Menstruation',
#   'tail_cui': 'C0156404',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'symptom'},
#  {'head': 'Perimenopause',
#   'head_cui': 'C0993589',
#   'head_semantic_source': 'MTH',
#   'relation': 'causes',
#   'tail': 'Hot flushes',
#   'tail_cui': 'C0600142',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'symptom'},
#  {'head': 'Perimenopause',
#   'head_cui': 'C0993589',
#   'head_semantic_source': 'MTH',
#   'relation': 'causes',
#   'tail': 'Mood swings',
#   'tail_cui': 'C0085633',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'symptom'},
#  {'head': 'Postmenopause',
#   'head_cui': 'C0206159',
#   'head_semantic_source': 'MSH',
#   'relation': 'is_a_stage_of',
#   'tail': 'Menopause',
#   'tail_cui': 'C0025320',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'condition'},
#  {'head': 'Postmenopause',
#   'head_cui': 'C0206159',
#   'head_semantic_source': 'MSH',
#   'relation': 'increases_risk_of',
#   'tail': 'Osteoporosis',
#   'tail_cui': 'C0029456',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'condition'},
#  {'head': 'Postmenopause',
#   'head_cui': 'C0206159',
#   'head_semantic_source': 'MSH',
#   'relation': 'increases_risk_of',
#   'tail': 'Heart Diseases',
#   'tail_cui': 'C0018799',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'condition'},
#  {'head': 'Premature Menopause',
#   'head_cui': 'C0025322',
#   'head_semantic_source': 'MTH',
#   'relation': 'occurs_before_age',
#   'tail': 'Pack size 45',
#   'tail_cui': 'C0470234',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'population'},
#  {'head': 'Premature Menopause',
#   'head_cui': 'C0025322',
#   'head_semantic_source': 'MTH',
#   'relation': 'occurs_at_or_before_age',
#   'tail': 'Human Papillomavirus-40',
#   'tail_cui': 'C5575815',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'population'},
#  {'head': 'Turner Syndrome',
#   'head_cui': 'C0041408',
#   'head_semantic_source': 'MTH',
#   'relation': 'is_a_type_of',
#   'tail': 'Premature Menopause',
#   'tail_cui': 'C0025322',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'condition'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'average_age',
#   'tail': '52 years old',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'condition',
#   'tail_type': 'outcome'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'transition_begins',
#   'tail': 'mid-40s',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'condition',
#   'tail_type': 'outcome'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'symptom',
#   'tail': 'Irregular Menstruation',
#   'tail_cui': 'C0156404',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'symptom'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'symptom',
#   'tail': 'Hot flushes',
#   'tail_cui': 'C0600142',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'symptom'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'symptom',
#   'tail': 'Night sweats',
#   'tail_cui': 'C0028081',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'symptom'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'symptom',
#   'tail': 'Hot and cold flashes',
#   'tail_cui': 'C4718498',
#   'tail_semantic_source': 'NOC',
#   'head_type': 'condition',
#   'tail_type': 'symptom'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'symptom',
#   'tail': 'Vaginal dryness',
#   'tail_cui': 'C0241633',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'symptom'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'symptom',
#   'tail': 'Urgency of micturition',
#   'tail_cui': 'C0085606',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'symptom'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'symptom',
#   'tail': 'Difficulty sleeping',
#   'tail_cui': 'C0235162',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'symptom'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'symptom',
#   'tail': 'Emotional changes with aging',
#   'tail_cui': 'C1821106',
#   'tail_semantic_source': 'NOC',
#   'head_type': 'condition',
#   'tail_type': 'symptom'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'symptom',
#   'tail': 'Dry skin',
#   'tail_cui': 'C0151908',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'symptom'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'symptom',
#   'tail': 'Dry Eyes brand of ocular lubricant',
#   'tail_cui': 'C0720056',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'symptom'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'symptom',
#   'tail': 'Xerostomia',
#   'tail_cui': 'C0043352',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'symptom'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'symptom',
#   'tail': 'worsening premenstrual syndrome',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'condition',
#   'tail_type': 'symptom'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'symptom',
#   'tail': 'Tenderness of breast',
#   'tail_cui': 'C0262397',
#   'tail_semantic_source': 'SNOMEDCT_US',
#   'head_type': 'condition',
#   'tail_type': 'symptom'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'symptom',
#   'tail': 'Tachycardia',
#   'tail_cui': 'C0039231',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'symptom'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'symptom',
#   'tail': 'Headache',
#   'tail_cui': 'C0018681',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'symptom'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'symptom',
#   'tail': 'Bothered by Aching in Muscles and Joints Question',
#   'tail_cui': 'C5959851',
#   'tail_semantic_source': 'NCI',
#   'head_type': 'condition',
#   'tail_type': 'symptom'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'symptom',
#   'tail': 'change in sexual interest',
#   'tail_cui': 'C1821937',
#   'tail_semantic_source': 'MEDCIN',
#   'head_type': 'condition',
#   'tail_type': 'symptom'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'symptom',
#   'tail': 'Difficulty concentrating',
#   'tail_cui': 'C0947509',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'symptom'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'symptom',
#   'tail': 'Memory lapses',
#   'tail_cui': 'C0557932',
#   'tail_semantic_source': 'SNOMEDCT_US',
#   'head_type': 'condition',
#   'tail_type': 'symptom'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'symptom',
#   'tail': 'Weight Gain',
#   'tail_cui': 'C0043094',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'symptom'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'symptom',
#   'tail': 'Have Hair Loss',
#   'tail_cui': 'C3898953',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'symptom'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'symptom',
#   'tail': 'Alopecia',
#   'tail_cui': 'C0002170',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'symptom'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'caused_by',
#   'tail': 'changes in hormone levels',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'condition',
#   'tail_type': 'biomarker'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'duration',
#   'tail': 'Recommended follow-up interval for repeat colonoscopy of at least 10 years documented in colonoscopy report (End/Polyp)',
#   'tail_cui': 'C2368529',
#   'tail_semantic_source': 'CPT',
#   'head_type': 'condition',
#   'tail_type': 'outcome'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'average_symptom_duration',
#   'tail': 'Tdap vaccine seven years of age and above',
#   'tail_cui': 'C2321357',
#   'tail_semantic_source': 'MEDCIN',
#   'head_type': 'condition',
#   'tail_type': 'outcome'},
#  {'head': 'Postmenopause',
#   'head_cui': 'C0206159',
#   'head_semantic_source': 'MSH',
#   'relation': 'follows',
#   'tail': 'Menopause',
#   'tail_cui': 'C0025320',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'condition'},
#  {'head': 'Postmenopause',
#   'head_cui': 'C0206159',
#   'head_semantic_source': 'MSH',
#   'relation': 'symptom_outcome',
#   'tail': 'symptoms ease up or disappear',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'condition',
#   'tail_type': 'outcome'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'natural_cause',
#   'tail': 'Aging',
#   'tail_cui': 'C0001811',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'condition'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'induced_by',
#   'tail': 'Medical and Surgical @ Female Reproductive System @ Removal @ Ovary',
#   'tail_cui': 'C2381863',
#   'tail_semantic_source': 'ICD10PCS',
#   'head_type': 'condition',
#   'tail_type': 'intervention'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'defined_by',
#   'tail': '12 consecutive months without a menstrual period',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'condition',
#   'tail_type': 'outcome'},
#  {'head': 'vaginal bleeding after menopause',
#   'head_cui': None,
#   'head_semantic_source': None,
#   'relation': 'may_indicate',
#   'tail': 'more serious health issue',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'symptom',
#   'tail_type': 'condition'},
#  {'head': 'Aging',
#   'head_cui': 'C0001811',
#   'head_semantic_source': 'MTH',
#   'relation': 'causes',
#   'tail': 'reproductive cycle slowing',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'condition',
#   'tail_type': 'condition'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'is_a_stage_of',
#   'tail': 'reproductive cycle slowing',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'condition',
#   'tail_type': 'condition'},
#  {'head': 'Both ovaries',
#   'head_cui': 'C0227898',
#   'head_semantic_source': 'MTH',
#   'relation': 'produce',
#   'tail': 'Estrogen measurement',
#   'tail_cui': 'C0202006',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'anatomical structure',
#   'tail_type': 'biomarker'},
#  {'head': 'Both ovaries',
#   'head_cui': 'C0227898',
#   'head_semantic_source': 'MTH',
#   'relation': 'produce',
#   'tail': 'progesterone',
#   'tail_cui': 'C0033308',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'anatomical structure',
#   'tail_type': 'biomarker'},
#  {'head': 'Estrogen measurement',
#   'head_cui': 'C0202006',
#   'head_semantic_source': 'MTH',
#   'relation': 'influences',
#   'tail': 'calcium usage',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'biomarker',
#   'tail_type': 'biological process'},
#  {'head': 'Estrogen measurement',
#   'head_cui': 'C0202006',
#   'head_semantic_source': 'MTH',
#   'relation': 'maintains',
#   'tail': 'Cholesterol level test result',
#   'tail_cui': 'C0428466',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'biomarker',
#   'tail_type': 'biological process'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'is_diagnosed_by',
#   'tail': 'Perimenopausal 6 to 12 Months Since LMP Question',
#   'tail_cui': 'C5203998',
#   'tail_semantic_source': 'NCI',
#   'head_type': 'condition',
#   'tail_type': 'diagnostic criterion'},
#  {'head': 'Hormone replacement therapy',
#   'head_cui': 'C0282402',
#   'head_semantic_source': 'MTH',
#   'relation': 'treats',
#   'tail': 'Symptoms such as flushing, sleeplessness, headache, lack of concentration, associated with premature menopause',
#   'tail_cui': 'C2874197',
#   'tail_semantic_source': 'ICD10CM',
#   'head_type': 'treatment',
#   'tail_type': 'symptom'},
#  {'head': 'Hormone Therapy',
#   'head_cui': 'C0279025',
#   'head_semantic_source': 'MTH',
#   'relation': 'treats',
#   'tail': 'Symptoms such as flushing, sleeplessness, headache, lack of concentration, associated with premature menopause',
#   'tail_cui': 'C2874197',
#   'tail_semantic_source': 'ICD10CM',
#   'head_type': 'treatment',
#   'tail_type': 'symptom'},
#  {'head': 'Estrogen Therapy',
#   'head_cui': 'C0279494',
#   'head_semantic_source': 'MTH',
#   'relation': 'is_a_type_of',
#   'tail': 'Hormone Therapy',
#   'tail_cui': 'C0279025',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'treatment',
#   'tail_type': 'treatment'},
#  {'head': 'Estrogen Therapy',
#   'head_cui': 'C0279494',
#   'head_semantic_source': 'MTH',
#   'relation': 'treats',
#   'tail': 'Hot flushes',
#   'tail_cui': 'C0600142',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'treatment',
#   'tail_type': 'symptom'},
#  {'head': 'Estrogen Therapy',
#   'head_cui': 'C0279494',
#   'head_semantic_source': 'MTH',
#   'relation': 'treats',
#   'tail': 'Vaginal dryness',
#   'tail_cui': 'C0241633',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'treatment',
#   'tail_type': 'symptom'},
#  {'head': 'Estrogen Therapy',
#   'head_cui': 'C0279494',
#   'head_semantic_source': 'MTH',
#   'relation': 'prevents',
#   'tail': 'Osteoporosis',
#   'tail_cui': 'C0029456',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'treatment',
#   'tail_type': 'condition'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'is_a_natural_process',
#   'tail': 'Online Adaptive Proton Stereotactic Body Radiation Therapy',
#   'tail_cui': 'C5959056',
#   'tail_semantic_source': 'NCI',
#   'head_type': 'condition',
#   'tail_type': 'biological process'},
#  {'head': 'Menopause',
#   'head_cui': 'C0025320',
#   'head_semantic_source': 'MTH',
#   'relation': 'is_diagnosed_by',
#   'tail': 'blood hormone levels (lab test)',
#   'tail_cui': 'C0428355',
#   'tail_semantic_source': 'MTH',
#   'head_type': 'condition',
#   'tail_type': 'diagnostic test'},
#  {'head': 'Hormone replacement therapy',
#   'head_cui': 'C0282402',
#   'head_semantic_source': 'MTH',
#   'relation': 'is_offered_to',
#   'tail': 'people experiencing menopause before age 40',
#   'tail_cui': None,
#   'tail_semantic_source': None,
#   'head_type': 'treatment',
#   'tail_type': 'population'},
#  ...]

# %% [markdown]
# ## Cleaning step 2: keep 1 relation

# %%
from collections import Counter, defaultdict

# Compute overall relation frequency
relation_counts = Counter(t["relation"] for t in standardized)

# Build mapping: (head, tail) → list of relations
pair_relations = defaultdict(list)
for t in standardized:
    key = (t["head"], t["tail"])
    pair_relations[key].append(t["relation"])

# Identify conflict pairs
conflicts = {k: set(v) for k, v in pair_relations.items() if len(set(v)) > 1}

print(f"Found {len(conflicts)} conflicting head–tail pairs.\n")
# Out:
# Found 54 conflicting head–tail pairs.

# %%
conflicts
# Out:
# {('Bonviva', 'Increased bone mineral density of lumbar spine'): {'affects',
#   'increases'},
#  ('ibandronate', 'risedronate'): {'is_preferred_over', 'preferred_over'},
#  ('denosumab', 'Increased bone mineral density of lumbar spine'): {'affects',
#   'improves',
#   'increases'},
#  ('denosumab', 'total hip bone mineral density'): {'affects',
#   'improves',
#   'increases'},
#  ('Hot flushes', 'Menopause'): {'associated_with',
#   'lasts_after',
#   'may_occur_during'},
#  ('romosozumab', 'bone mineral density at the lumbar spine'): {'affects',
#   'increases'},
#  ('denosumab', 'bone mineral density at lumbar spine'): {'affects',
#   'increases'},
#  ('romosozumab', 'bone mineral density at the femoral neck'): {'affects',
#   'increases'},
#  ('romosozumab', 'bone mineral density at the total hip'): {'affects',
#   'increases'},
#  ('postmenopausal women with osteoporosis', 'romosozumab'): {'receives',
#   'treated_with'},
#  ('Premature Menopause',
#   'Human Papillomavirus-40'): {'occurs_at_or_before_age', 'occurs_before_age'},
#  ('Turner Syndrome', 'Premature Menopause'): {'causes',
#   'is_a_type_of',
#   'is_different_from'},
#  ('custom-mixed bioidentical hormones',
#   'conventional hormone therapy'): {'are_not_more_effective_than', 'may_be_riskier_than'},
#  ('Dietary Supplements', 'Pharmaceutical Preparations'): {'interact_with',
#   'may_have_harmful_side_effects',
#   'may_interact_with'},
#  ('Menopause',
#   'menstrual periods stopped permanently'): {'is_characterized_by', 'is_the_time_when'},
#  ('Hormone Therapy', 'Malignant neoplasm of breast'): {'associated_risk_of',
#   'may_increase_risk_of'},
#  ('Yoga', 'Anxiety'): {'may_help_with', 'reduces'},
#  ('Yoga', 'Mental Depression'): {'may_help_with', 'reduces'},
#  ('menopausal transition', 'Menopause'): {'is_a_stage_of',
#   'may_be_referred_to_as',
#   'precedes'},
#  ('Menopause', 'Irregular Menstruation'): {'has_symptom', 'symptom'},
#  ('Menopause', 'Hot flushes'): {'causes',
#   'has_symptom',
#   'is_a_symptom_of',
#   'symptom'},
#  ('Menopause', 'Night sweats'): {'has_symptom', 'symptom'},
#  ('Menopause', 'Trouble Sleeping Question'): {'causes', 'has_symptom'},
#  ('Menopause', 'Vaginal dryness'): {'causes',
#   'has_symptom',
#   'is_a_symptom_of',
#   'symptom'},
#  ('Menopause', 'Mood swings'): {'causes', 'has_symptom', 'is_a_symptom_of'},
#  ('Hormone replacement therapy', 'Hot flushes'): {'reduces',
#   'relieves',
#   'treats'},
#  ('Hormone replacement therapy', 'Vaginal dryness'): {'relieves', 'treats'},
#  ('Low estrogen levels', 'Osteoporosis'): {'causes', 'raise_risk_of'},
#  ('Hormone replacement therapy',
#   'Symptoms such as flushing, sleeplessness, headache, lack of concentration, associated with premature menopause'): {'approved_to_relieve',
#   'may_mitigate',
#   'relieves',
#   'treats'},
#  ('Physical activity', 'Mood (psychological function)'): {'can_lift',
#   'improves'},
#  ('calcium', 'Caltrate Bone Health 600+D3 Tablet'): {'is_important_for',
#   'maintains'},
#  ('vitamin D', 'Caltrate Bone Health 600+D3 Tablet'): {'important_for',
#   'is_important_for'},
#  ('Menopause',
#   'Risk to the life of the pregnant woman greater than if the pregnancy was terminated'): {'is_a_part_of',
#   'is_a_stage_of'},
#  ('Menopause', 'Aging'): {'is_a_natural_process',
#   'is_a_part_of',
#   'natural_cause'},
#  ('menopausal transition', 'Hot flushes'): {'causes', 'includes_symptom'},
#  ('Vaginal dryness', 'Menopause'): {'is_more_common_after', 'occurs_during'},
#  ('Menopause', 'Difficulty sleeping'): {'has_symptom', 'symptom'},
#  ('Hormone replacement therapy',
#   'Malignant neoplasm of breast'): {'does_not_increase_risk', 'may_increase_risk_of'},
#  ('Hormone replacement therapy', 'Blood Clot'): {'may_increase_risk_of',
#   'raises_risk_of'},
#  ('gabapentin', 'Hot flushes'): {'helps_reduce', 'may_mitigate', 'treats'},
#  ('Menopause',
#   '12 consecutive months without a menstrual period'): {'defined_by', 'is_diagnosed_after'},
#  ('Perimenopause', 'Menopause'): {'begins_before',
#   'is_a_stage_of',
#   'is_a_transition_to'},
#  ('Perimenopause', 'Irregular Menstruation'): {'causes',
#   'is_characterized_by'},
#  ('Perimenopause', 'Hot flushes'): {'causes', 'is_characterized_by'},
#  ('Postmenopause', 'Menopause'): {'follows', 'is_a_stage_of'},
#  ('Menopause', 'Difficulty concentrating'): {'causes', 'symptom'},
#  ('Menopause', 'Weight Gain'): {'causes', 'symptom'},
#  ('Menopause',
#   'Perimenopausal 6 to 12 Months Since LMP Question'): {'is_diagnosed_by',
#   'is_reached_after'},
#  ('fezolinetant', 'Hot flushes'): {'may_mitigate', 'treats'},
#  ('Irregular Menstruation', 'Menopause'): {'is_a_symptom_of',
#   'may_be_a_sign_of'},
#  ('Menopause', 'Irritability - emotion'): {'causes', 'is_a_symptom_of'},
#  ("women's health initiative",
#   'Obtain multiple measurements of endometrial thickness from various angles for women presenting with postmenopausal bleeding'): {'enrolled',
#   'targets_population'},
#  ('Menopause', 'low levels of estrogen and progesterone'): {'associated_with',
#   'causes'},
#  ('Hormone replacement therapy',
#   'Stroke (heart beat)'): {'may_increase_risk_of', 'raises_risk_of'}}

# %%
def pick_best_relation(rel_set):
    rel_list = list(rel_set)

    # 1. If "affects" is present AND there are other more specific relations → remove it
    if "affects" in rel_set and len(rel_set) > 1:
        rel_list = [r for r in rel_list if r != "affects"]

    # 2. Rank remaining relations by global frequency (descending)
    rel_list.sort(key=lambda r: relation_counts[r], reverse=True)

    # 3. If tie, lexicographically break the tie
    # (stable sort ensures lexicographic only applies when frequencies are equal)
    return rel_list[0]

# %%
cleaned_triples = []
change_report = []

for (head, tail), relations in conflicts.items():
    best = pick_best_relation(relations)

    # Record the decision
    change_report.append({
        "head": head,
        "tail": tail,
        "relations": sorted(list(relations)),
        "kept": best
    })

# %%
for t in standardized:
    key = (t["head"], t["tail"])
    if key in conflicts:
        # keep only if relation == chosen best
        if t["relation"] == [r for r in change_report if r["head"] == key[0] and r["tail"] == key[1]][0]["kept"]:
            cleaned_triples.append(t)
    else:
        cleaned_triples.append(t)

print(f"Original triples: {len(standardized)}")
print(f"After resolving relation conflicts: {len(cleaned_triples)}")
print(f"Removed {len(standardized) - len(cleaned_triples)} redundant triples.")
# Out:
# Original triples: 1322
# After resolving relation conflicts: 1243
# Removed 79 redundant triples.

# %%
print("\n=== Relation Conflict Resolution Report ===\n")
for item in change_report:
    print(f"- {item['head']}  ↔  {item['tail']}")
    print(f"  Relations: {item['relations']}  →  kept **{item['kept']}**\n")
# Out:
# === Relation Conflict Resolution Report ===
#
# - Bonviva  ↔  Increased bone mineral density of lumbar spine
#   Relations: ['affects', 'increases']  →  kept **increases**
#
# - ibandronate  ↔  risedronate
#   Relations: ['is_preferred_over', 'preferred_over']  →  kept **preferred_over**
#
# - denosumab  ↔  Increased bone mineral density of lumbar spine
#   Relations: ['affects', 'improves', 'increases']  →  kept **increases**
#
# - denosumab  ↔  total hip bone mineral density
#   Relations: ['affects', 'improves', 'increases']  →  kept **increases**
#
# - Hot flushes  ↔  Menopause
#   Relations: ['associated_with', 'lasts_after', 'may_occur_during']  →  kept **associated_with**
#
# - romosozumab  ↔  bone mineral density at the lumbar spine
#   Relations: ['affects', 'increases']  →  kept **increases**
#
# - denosumab  ↔  bone mineral density at lumbar spine
#   Relations: ['affects', 'increases']  →  kept **increases**
#
# - romosozumab  ↔  bone mineral density at the femoral neck
#   Relations: ['affects', 'increases']  →  kept **increases**
#
# - romosozumab  ↔  bone mineral density at the total hip
#   Relations: ['affects', 'increases']  →  kept **increases**
#
# - postmenopausal women with osteoporosis  ↔  romosozumab
#   Relations: ['receives', 'treated_with']  →  kept **receives**
#
# - Premature Menopause  ↔  Human Papillomavirus-40
#   Relations: ['occurs_at_or_before_age', 'occurs_before_age']  →  kept **occurs_before_age**
#
# - Turner Syndrome  ↔  Premature Menopause
#   Relations: ['causes', 'is_a_type_of', 'is_different_from']  →  kept **causes**
#
# - custom-mixed bioidentical hormones  ↔  conventional hormone therapy
#   Relations: ['are_not_more_effective_than', 'may_be_riskier_than']  →  kept **may_be_riskier_than**
#
# - Dietary Supplements  ↔  Pharmaceutical Preparations
#   Relations: ['interact_with', 'may_have_harmful_side_effects', 'may_interact_with']  →  kept **may_interact_with**
#
# - Menopause  ↔  menstrual periods stopped permanently
#   Relations: ['is_characterized_by', 'is_the_time_when']  →  kept **is_characterized_by**
#
# - Hormone Therapy  ↔  Malignant neoplasm of breast
#   Relations: ['associated_risk_of', 'may_increase_risk_of']  →  kept **may_increase_risk_of**
#
# - Yoga  ↔  Anxiety
#   Relations: ['may_help_with', 'reduces']  →  kept **reduces**
#
# - Yoga  ↔  Mental Depression
#   Relations: ['may_help_with', 'reduces']  →  kept **reduces**
#
# - menopausal transition  ↔  Menopause
#   Relations: ['is_a_stage_of', 'may_be_referred_to_as', 'precedes']  →  kept **is_a_stage_of**
#
# - Menopause  ↔  Irregular Menstruation
#   Relations: ['has_symptom', 'symptom']  →  kept **has_symptom**
#
# - Menopause  ↔  Hot flushes
#   Relations: ['causes', 'has_symptom', 'is_a_symptom_of', 'symptom']  →  kept **causes**
#
# - Menopause  ↔  Night sweats
#   Relations: ['has_symptom', 'symptom']  →  kept **has_symptom**
#
# - Menopause  ↔  Trouble Sleeping Question
#   Relations: ['causes', 'has_symptom']  →  kept **causes**
#
# - Menopause  ↔  Vaginal dryness
#   Relations: ['causes', 'has_symptom', 'is_a_symptom_of', 'symptom']  →  kept **causes**
#
# - Menopause  ↔  Mood swings
#   Relations: ['causes', 'has_symptom', 'is_a_symptom_of']  →  kept **causes**
#
# - Hormone replacement therapy  ↔  Hot flushes
#   Relations: ['reduces', 'relieves', 'treats']  →  kept **reduces**
#
# - Hormone replacement therapy  ↔  Vaginal dryness
#   Relations: ['relieves', 'treats']  →  kept **treats**
#
# - Low estrogen levels  ↔  Osteoporosis
#   Relations: ['causes', 'raise_risk_of']  →  kept **causes**
#
# - Hormone replacement therapy  ↔  Symptoms such as flushing, sleeplessness, headache, lack of concentration, associated with premature menopause
#   Relations: ['approved_to_relieve', 'may_mitigate', 'relieves', 'treats']  →  kept **treats**
#
# - Physical activity  ↔  Mood (psychological function)
#   Relations: ['can_lift', 'improves']  →  kept **improves**
#
# - calcium  ↔  Caltrate Bone Health 600+D3 Tablet
#   Relations: ['is_important_for', 'maintains']  →  kept **maintains**
#
# - vitamin D  ↔  Caltrate Bone Health 600+D3 Tablet
#   Relations: ['important_for', 'is_important_for']  →  kept **is_important_for**
#
# - Menopause  ↔  Risk to the life of the pregnant woman greater than if the pregnancy was terminated
#   Relations: ['is_a_part_of', 'is_a_stage_of']  →  kept **is_a_stage_of**
#
# - Menopause  ↔  Aging
#   Relations: ['is_a_natural_process', 'is_a_part_of', 'natural_cause']  →  kept **is_a_part_of**
#
# - menopausal transition  ↔  Hot flushes
#   Relations: ['causes', 'includes_symptom']  →  kept **causes**
#
# - Vaginal dryness  ↔  Menopause
#   Relations: ['is_more_common_after', 'occurs_during']  →  kept **is_more_common_after**
#
# - Menopause  ↔  Difficulty sleeping
#   Relations: ['has_symptom', 'symptom']  →  kept **has_symptom**
#
# - Hormone replacement therapy  ↔  Malignant neoplasm of breast
#   Relations: ['does_not_increase_risk', 'may_increase_risk_of']  →  kept **may_increase_risk_of**
#
# - Hormone replacement therapy  ↔  Blood Clot
#   Relations: ['may_increase_risk_of', 'raises_risk_of']  →  kept **may_increase_risk_of**
#
# - gabapentin  ↔  Hot flushes
#   Relations: ['helps_reduce', 'may_mitigate', 'treats']  →  kept **treats**
#
# - Menopause  ↔  12 consecutive months without a menstrual period
#   Relations: ['defined_by', 'is_diagnosed_after']  →  kept **is_diagnosed_after**
#
# - Perimenopause  ↔  Menopause
#   Relations: ['begins_before', 'is_a_stage_of', 'is_a_transition_to']  →  kept **is_a_stage_of**
#
# - Perimenopause  ↔  Irregular Menstruation
#   Relations: ['causes', 'is_characterized_by']  →  kept **causes**
#
# - Perimenopause  ↔  Hot flushes
#   Relations: ['causes', 'is_characterized_by']  →  kept **causes**
#
# - Postmenopause  ↔  Menopause
#   Relations: ['follows', 'is_a_stage_of']  →  kept **is_a_stage_of**
#
# - Menopause  ↔  Difficulty concentrating
#   Relations: ['causes', 'symptom']  →  kept **causes**
#
# - Menopause  ↔  Weight Gain
#   Relations: ['causes', 'symptom']  →  kept **causes**
#
# - Menopause  ↔  Perimenopausal 6 to 12 Months Since LMP Question
#   Relations: ['is_diagnosed_by', 'is_reached_after']  →  kept **is_diagnosed_by**
#
# - fezolinetant  ↔  Hot flushes
#   Relations: ['may_mitigate', 'treats']  →  kept **treats**
#
# - Irregular Menstruation  ↔  Menopause
#   Relations: ['is_a_symptom_of', 'may_be_a_sign_of']  →  kept **is_a_symptom_of**
#
# - Menopause  ↔  Irritability - emotion
#   Relations: ['causes', 'is_a_symptom_of']  →  kept **causes**
#
# - women's health initiative  ↔  Obtain multiple measurements of endometrial thickness from various angles for women presenting with postmenopausal bleeding
#   Relations: ['enrolled', 'targets_population']  →  kept **targets_population**
#
# - Menopause  ↔  low levels of estrogen and progesterone
#   Relations: ['associated_with', 'causes']  →  kept **causes**
#
# - Hormone replacement therapy  ↔  Stroke (heart beat)
#   Relations: ['may_increase_risk_of', 'raises_risk_of']  →  kept **may_increase_risk_of**

# %% [markdown]
# ## Cleaning step 3: Remove duplicate triples

# %%
# Remove duplicates based on (head, relation, tail)
unique_triples = []
seen = set()

for t in cleaned_triples:  
    key = (t["head"], t["relation"], t["tail"])
    if key not in seen:
        unique_triples.append(t)
        seen.add(key)

print(f"Before deduplication: {len(cleaned_triples)} triples")
print(f"After deduplication:  {len(unique_triples)} triples")
print(f"Removed {len(cleaned_triples) - len(unique_triples)} duplicates.")
# Out:
# Before deduplication: 1243 triples
# After deduplication:  1197 triples
# Removed 46 duplicates.

# %%
# to view duplicates
from collections import Counter

keys = [(t["head"], t["relation"], t["tail"]) for t in cleaned_triples]
counts = Counter(keys)

duplicates = [k for k, v in counts.items() if v > 1]

print("Duplicate triples:")
for k in duplicates:
    print(f"  {k}  → appears {counts[k]} times")
# Out:
# Duplicate triples:
#   ('Bonviva', 'treats', 'Osteoporosis, Postmenopausal')  → appears 2 times
#   ('vitamin D', 'supplementation_with', 'Osteoporosis, Postmenopausal')  → appears 2 times
#   ('calcium', 'supplementation_with', 'Osteoporosis, Postmenopausal')  → appears 2 times
#   ('Bonviva', 'increases', 'Increased bone mineral density of lumbar spine')  → appears 2 times
#   ('Both ovaries', 'produce', 'Estrogen measurement')  → appears 2 times
#   ('Both ovaries', 'produce', 'progesterone')  → appears 2 times
#   ('Obtain multiple measurements of endometrial thickness from various angles for women presenting with postmenopausal bleeding', 'has_condition', 'Osteoporosis')  → appears 5 times
#   ('Esmirtazapine', 'treats', 'Vasomotor menopausal symptoms')  → appears 2 times
#   ('Vasomotor menopausal symptoms', 'associated_with', 'Menopause')  → appears 2 times
#   ('mk-6913', 'reduces', 'Hot flushes')  → appears 2 times
#   ('denosumab', 'increases', 'bone mineral density at lumbar spine')  → appears 2 times
#   ('romosozumab', 'treats', 'Osteoporosis, Postmenopausal')  → appears 2 times
#   ('romosozumab', 'increases', 'bone mineral density at the lumbar spine')  → appears 3 times
#   ('romosozumab', 'increases', 'bone mineral density at the femoral neck')  → appears 2 times
#   ('romosozumab', 'increases', 'bone mineral density at the total hip')  → appears 2 times
#   ('denosumab', 'treats', 'Osteoporosis')  → appears 2 times
#   ('estradiol vaginal softgel capsules', 'improves', 'vaginal mucosa assessment')  → appears 3 times
#   ('tx-12-004-hr', 'affects', 'maturation index of vaginal cell type')  → appears 3 times
#   ('Premature Menopause', 'occurs_before_age', 'Human Papillomavirus-40')  → appears 2 times
#   ('Premature Menopause', 'occurs_before_age', 'Pack size 45')  → appears 2 times
#   ('Smoking', 'causes', 'Premature Menopause')  → appears 2 times
#   ('Family Medical History', 'increases_likelihood_of', 'Premature Menopause')  → appears 2 times
#   ('Yoga', 'is_as_effective_as', 'other types of exercise')  → appears 2 times
#   ('Menopause', 'is_a_type_of', 'Menopause')  → appears 2 times
#   ('menopausal transition', 'is_a_type_of', 'Perimenopause')  → appears 2 times
#   ('Lifestyle changes', 'may_mitigate', 'Symptoms such as flushing, sleeplessness, headache, lack of concentration, associated with premature menopause')  → appears 2 times
#   ('Symptoms such as flushing, sleeplessness, headache, lack of concentration, associated with premature menopause', 'include', 'Hot flushes')  → appears 2 times
#   ('Condoms, Male', 'prevent', 'Sexually Transmitted Diseases')  → appears 2 times
#   ('Menopause', 'is_not', 'Disease')  → appears 2 times
#   ('Menopause', 'increases_risk_of', 'Heart Diseases')  → appears 2 times
#   ('Menopause', 'increases_risk_of', 'Osteoporosis')  → appears 3 times
#   ('Difficulty sleeping', 'can_lead_to', 'Fatigue')  → appears 2 times
#   ('Hormone replacement therapy', 'may_increase_risk_of', 'Malignant neoplasm of breast')  → appears 2 times
#   ('Hormone replacement therapy', 'may_increase_risk_of', 'Blood Clot')  → appears 2 times
#   ('Menopause', 'occurs_at_average_age', 'Fifty-two')  → appears 2 times
#   ('Hormone Therapy', 'treats', 'Symptoms such as flushing, sleeplessness, headache, lack of concentration, associated with premature menopause')  → appears 2 times
#   ('Hormone replacement therapy', 'treats', 'Symptoms such as flushing, sleeplessness, headache, lack of concentration, associated with premature menopause')  → appears 3 times
#   ('fezolinetant', 'treats', 'Hot flushes')  → appears 2 times

# %%
len(duplicates)
# Out:
# 38

# %% [markdown]
# ## saved

# %%
import json

OUT_PATH = "/Users/cj2837/Documents/Courses/Project/outputs/mapped_triples.json"

with open(OUT_PATH, "w") as f:
    json.dump(unique_triples, f, indent=2, ensure_ascii=False)

print("Saved standardized triples to:", OUT_PATH)
print("Total triples saved:", len(unique_triples))
# Out:
# ✅ Saved standardized triples to: /Users/cj2837/Documents/Courses/Project/outputs/mapped_triples.json
# Total triples saved: 1197

# %% [markdown]
# ## Sanity Checks

# %% [markdown]
# #### Node types

# %%
# to check node types
from collections import defaultdict

# Counters
type_to_nodes = defaultdict(set)   # maps type → set of node names

for t in unique_triples: 
    h, ht = t.get("head"), t.get("head_type")
    ta, tat = t.get("tail"), t.get("tail_type")
    
    if ht:
        type_to_nodes[ht].add(h)
    if tat:
        type_to_nodes[tat].add(ta)

# ---- Print nicely ----
print("=== Node Types Summary ===\n")
total_types = len(type_to_nodes)

for node_type, nodes in sorted(type_to_nodes.items()):
    count = len(nodes)
    example = next(iter(nodes)) if nodes else "N/A"

    print(f"• {node_type}: {count} nodes")
    print(f"    example: {example}\n")

print(f"Total node types: {total_types}")
# Out:
# === Node Types Summary ===
#
# • biological process: 5 nodes
#     example: calcium usage
#
# • biomarker: 103 nodes
#     example: Epithelial cells.parabasal | Vaginal | Hematology and Cell counts
#
# • condition: 119 nodes
#     example: inflammatory disorders such as rheumatoid arthritis and postmenopausal osteoporosis
#
# • diagnostic criterion: 1 nodes
#     example: Perimenopausal 6 to 12 Months Since LMP Question
#
# • diagnostic test: 1 nodes
#     example: blood hormone levels (lab test)
#
# • event: 1 nodes
#     example: final menstrual period
#
# • finding: 1 nodes
#     example: hormone replacement therapy did not prevent heart disease
#
# • food: 2 nodes
#     example: soy containing foods
#
# • intervention: 79 nodes
#     example: having sex more often
#
# • lifestyle factor: 28 nodes
#     example: Date quit tobacco smoking
#
# • measurement: 1 nodes
#     example: One to two times per year
#
# • medication: 27 nodes
#     example: fluoxetine
#
# • organization: 9 nodes
#     example: nccih-funded researchers
#
# • outcome: 293 nodes
#     example: areal bmd at the femoral neck
#
# • population: 44 nodes
#     example: premenopausal-aged female veterans
#
# • process: 2 nodes
#     example: Aging
#
# • research: 3 nodes
#     example: effects of acupuncture on hot flashes
#
# • research study: 1 nodes
#     example: study of women’s health across the nation
#
# • risk: 15 nodes
#     example: younger age at menopause
#
# • risk factor: 1 nodes
#     example: Family Medical History
#
# • study: 7 nodes
#     example: whi observational study
#
# • study type: 7 nodes
#     example: Observational Study
#
# • supplement: 15 nodes
#     example: Kava
#
# • surgery: 2 nodes
#     example: Bilateral oophorectomy
#
# • symptom: 160 nodes
#     example: cumulative amenorrhea
#
# • time period: 1 nodes
#     example: first few years after last period
#
# • timepoint: 1 nodes
#     example: Embryonic week 4
#
# • treatment: 121 nodes
#     example: nonhormonal treatments
#
# Total node types: 28

# %%
# to check Nodes with Multiple Assigned Types
from collections import defaultdict

# Map each node → set of assigned types
node_to_types = defaultdict(set)

for t in unique_triples:
    tail = t["tail"]
    head_type = t.get("head_type")
    tail_type = t.get("tail_type")

    if head_type:
        node_to_types[head].add(head_type)
    if tail_type:
        node_to_types[tail].add(tail_type)

# ---- Find conflicts ----
conflicts = {node: types for node, types in node_to_types.items() if len(types) > 1}

print("=== Nodes with Multiple Assigned Types ===\n")

if not conflicts:
    print("✅ No node appears with multiple types. (Good!)")
else:
    for node, types in conflicts.items():
        print(f"• {node}")
        print(f"   types: {sorted(types)}\n")

print(f"Total conflicted nodes: {len(conflicts)}")
# Out:
# === Nodes with Multiple Assigned Types ===
#
# • Hormone replacement therapy
#    types: ['biomarker', 'condition', 'event', 'food', 'intervention', 'lifestyle factor', 'medication', 'organization', 'outcome', 'population', 'research study', 'risk', 'risk factor', 'study', 'study type', 'supplement', 'surgery', 'symptom', 'treatment']
#
# • Bone Mineral Density Test
#    types: ['biomarker', 'outcome']
#
# • Increased bone mineral density of lumbar spine
#    types: ['biomarker', 'outcome']
#
# • Osteopenia
#    types: ['condition', 'outcome']
#
# • ibandronate
#    types: ['medication', 'treatment']
#
# • risedronate
#    types: ['medication', 'treatment']
#
# • Fracture
#    types: ['condition', 'outcome']
#
# • Menopausal symptom
#    types: ['condition', 'outcome', 'symptom']
#
# • cumulative amenorrhea
#    types: ['outcome', 'symptom']
#
# • Finding of hormone level
#    types: ['biological process', 'biomarker']
#
# • PRO-CTCAE V1.0 - Hot Flashes Severity
#    types: ['outcome', 'symptom']
#
# • loss of bone density
#    types: ['outcome', 'symptom']
#
# • Anxiety
#    types: ['condition', 'outcome', 'symptom']
#
# • bothersomeness of hot flashes
#    types: ['outcome', 'symptom']
#
# • PRO-CTCAE V1.0 - Hot Flashes Frequency
#    types: ['outcome', 'symptom']
#
# • Hip Fractures
#    types: ['condition', 'outcome']
#
# • Mental Depression
#    types: ['condition', 'symptom']
#
# • Hemorrhage
#    types: ['outcome', 'risk']
#
# • Menstrual spotting
#    types: ['outcome', 'symptom']
#
# • Vaginal pH
#    types: ['biomarker', 'outcome']
#
# • Mood (psychological function)
#    types: ['outcome', 'symptom']
#
# • Symptoms such as flushing, sleeplessness, headache, lack of concentration, associated with premature menopause
#    types: ['condition', 'symptom']
#
# • Weight Gain
#    types: ['outcome', 'symptom']
#
# • Hypertensive disease
#    types: ['biomarker', 'condition', 'outcome']
#
# • Hypercholesterolemia
#    types: ['biomarker', 'condition']
#
# • Bone Density
#    types: ['biomarker', 'outcome']
#
# • Infective vaginitis
#    types: ['condition', 'symptom']
#
# • Cholesterol level test result
#    types: ['biological process', 'biomarker']
#
# • moisture
#    types: ['outcome', 'symptom']
#
# Total conflicted nodes: 29

# %% [markdown]
# #### Relationship

# %%
from collections import Counter

# Count frequency of each relation
relation_counts = Counter(t["relation"] for t in unique_triples)

# Sort by count (descending)
sorted_relations = relation_counts.most_common()

print("Relations sorted by frequency:")
for relation, count in sorted_relations:
    print(f"{relation}: {count}")

print("\nTotal unique relations:", len(relation_counts))
# Out:
# Relations sorted by frequency:
# affects: 117
# reduces: 90
# increases: 62
# treats: 59
# causes: 51
# improves: 45
# increases_risk_of: 42
# includes: 38
# associated_with: 30
# has_symptom: 26
# is_a_type_of: 21
# include: 19
# may_mitigate: 18
# may_help_with: 17
# is_a_symptom_of: 16
# symptom: 15
# decreases: 12
# may_increase_risk_of: 11
# caused_by: 11
# studies: 9
# prevents: 8
# measured_by: 8
# reduces_risk_of: 8
# may_cause: 8
# receives: 7
# influences: 7
# includes_symptom: 7
# may_increase: 7
# studied_for: 7
# experiences: 6
# used_with: 6
# may_treat: 6
# linked_to: 6
# treat: 6
# administered_as: 6
# treated_with: 5
# recommended_for: 5
# is_a_stage_of: 5
# compared_to: 4
# assesses: 4
# generally_have: 4
# does_not_recommend: 4
# may_contribute_to: 4
# is_characterized_by: 4
# increase_risk_of: 4
# helps_with: 4
# can_lead_to: 4
# may_help: 4
# can_help_with: 4
# may_indicate: 4
# is_a_risk_factor_for: 4
# focuses_on: 4
# does_not_reduce_risk_of: 4
# can cause: 4
# secretes: 3
# has_condition: 3
# related_to: 3
# measured_in: 3
# prescribed_for: 3
# used_for: 3
# have_not_been_clearly_shown_to_relieve: 3
# may_interact_with: 3
# should_not_use: 3
# does_not_support: 3
# more_likely_to_have: 3
# can_make_worse: 3
# maintains: 3
# provides: 3
# contributes_to: 3
# more_likely_to_experience: 3
# increased_by: 3
# can_reduce: 3
# raises_risk_of: 3
# supplementation_with: 2
# compared_with: 2
# used for: 2
# associated with: 2
# has_dosing_frequency: 2
# acts_on: 2
# produce: 2
# modulates: 2
# has_outcome: 2
# contained_in: 2
# measures: 2
# occurs_before_age: 2
# increases_severity_of: 2
# may_have: 2
# approved: 2
# recommends_against: 2
# study: 2
# can_help: 2
# can_improve: 2
# raise_risk_of: 2
# is_not_related_to: 2
# prevent: 2
# promotes: 2
# weighed_against: 2
# is_a_part_of: 2
# is_associated_with: 2
# is_confirmed_after: 2
# is_important_during: 2
# are_common_during: 2
# may_be_treated_with: 2
# may_reduce_risk_of: 2
# is_diagnosed_by: 2
# is_an_option_for: 2
# can_make: 2
# can_increase: 2
# is_more_common_after: 2
# tied_to: 2
# is_a_form_of: 2
# does_not_increase_risk: 2
# provides_guidance_on: 2
# do_not_prevent: 2
# may last: 2
# may be: 2
# outcome_of: 1
# suppresses: 1
# preferred_over: 1
# transitioned_to: 1
# signals: 1
# target_of: 1
# blocks: 1
# manage: 1
# shows_superior_efficacy_to: 1
# protects: 1
# characterized_by: 1
# measured_at: 1
# induces: 1
# manages: 1
# at risk of: 1
# increases risk of: 1
# has: 1
# is_superior_to: 1
# targets: 1
# in_response_to: 1
# investigated_in: 1
# is_modulated_by: 1
# impairs: 1
# prevents_reduction_in: 1
# results_in: 1
# is_a_biomarker_for: 1
# may_improve: 1
# is: 1
# does_not_cause_immediate: 1
# increases_likelihood_of: 1
# has_not_been_shown_to_be_more_effective_than: 1
# is_as_effective_as: 1
# have_not_been_shown_to_be_safer_than: 1
# is_the_most_effective_for: 1
# less_effective_than: 1
# has_low_rate_of: 1
# may_be_riskier_than: 1
# has_no_regulatory_oversight: 1
# has_variable: 1
# recommends: 1
# conditionally_recommends: 1
# prefers: 1
# advises_caution_with: 1
# states: 1
# cautions_against: 1
# may_include: 1
# leads_to: 1
# can_lower_risk_of: 1
# helps_prevent: 1
# may_play_role_in: 1
# detect: 1
# screen_for: 1
# available_for: 1
# damages: 1
# may_be_effective_for: 1
# important_for: 1
# stimulates: 1
# regulate: 1
# mediates: 1
# activates: 1
# used_by: 1
# have_higher_risk_of: 1
# supported_by: 1
# part_of: 1
# is_not: 1
# less_likely_to_experience: 1
# is_a_likely_cause_of: 1
# can_result_from: 1
# is_important_for: 1
# aims_to_understand: 1
# are_related_to: 1
# can_last_for: 1
# may_manage: 1
# makes: 1
# does_not_prevent: 1
# begins_with: 1
# occurs_in: 1
# increases_during: 1
# consists_of: 1
# may_be_started_in: 1
# should_not_be_used_in: 1
# may_be_used_in: 1
# should_not_be_used_for: 1
# is_safe_in: 1
# should_have: 1
# is_safer_than: 1
# should_take: 1
# contains: 1
# should_be_included_in: 1
# strengthen: 1
# may_be_sign_of: 1
# is_caused_by: 1
# occurs_at_average_age: 1
# is_diagnosed_after: 1
# average_age: 1
# transition_begins: 1
# duration: 1
# average_symptom_duration: 1
# symptom_outcome: 1
# induced_by: 1
# is_a_natural_process: 1
# is_offered_to: 1
# boosts: 1
# cannot_be_used_alone: 1
# is_available_as: 1
# has_risk: 1
# are_good_options_for: 1
# are_found_in: 1
# help_with: 1
# tests: 1
# are_useful_for: 1
# is_useful_for: 1
# declines: 1
# is_slower_than: 1
# cause: 1
# may_lower: 1
# can_disturb: 1
# can_boost: 1
# can_lower: 1
# can_slow_down: 1
# can_strengthen: 1
# are_needed_after: 1
# funds: 1
# followed_by: 1
# designed_to_understand: 1
# has_similar_effects_to: 1
# showed_similar_effects_to: 1
# developed_by: 1
# may_have_connection_to: 1
# is_specific_to: 1
# is_a_hallmark_of: 1
# have_more_buildup_of: 1
# may_be_key_factors_for: 1
# face_disproportionate_burden_of: 1
# is_part_of: 1
# will_invite_back: 1
# targets_population: 1
# found: 1
# helps: 1
# sponsored_by: 1
# may_benefit: 1
# should_not_be_used_to_prevent: 1
# should_not_be_used_to_lower: 1
# provide_modest_benefit_for: 1
# age_range: 1
# tracked: 1
# aimed_to_develop: 1
# encourage: 1
# starts_in: 1
# lasts_for_average: 1
# may_occur_during: 1
# is_similar_to: 1
# may become: 1
# can lead to: 1
# can raise: 1
# can last: 1
# requires: 1
# may_go_away_without: 1
# may_not_be: 1
# replaces: 1
# does_not_treat: 1
# claimed_to_be: 1
# not_fda_approved: 1
#
# Total unique relations: 279

# %%
# same head and tail, but different relation

from collections import defaultdict

# Group relations by (head, tail)
pair_relations = defaultdict(set)

for t in unique_triples:
    key = (t["head"], t["tail"])
    pair_relations[key].add(t["relation"])

# Find cases where same head/tail appear with multiple relations
conflicts = {k: v for k, v in pair_relations.items() if len(v) > 1}

print(f"Found {len(conflicts)} head–tail pairs with conflicting relations:\n")

for (head, tail), relations in conflicts.items():
    print(f"- {head}  ↔  {tail}")
    print(f"  Relations: {sorted(list(relations))}\n")
# Out:
# Found 0 head–tail pairs with conflicting relations:
